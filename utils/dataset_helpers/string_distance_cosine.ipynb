# %%
#!/usr/bin/env python3
import pandas as pd
from pathlib import Path
import re
from typing import List

import torch
from sentence_transformers import SentenceTransformer, util

# %%
def read_text(path: Path) -> str:
    # Read as UTF-8; replace undecodable bytes so the comparison can proceed
    return path.read_text(encoding="utf-8", errors="replace")

# %%
def strip_comments_and_whitespace(text: str) -> str:
    """
    Text-only minifier:
      1) For each line, drop everything from first '#' to EOL.
      2) Remove ALL whitespace chars.
    NOTE: Treats '#' inside strings as comment starts (simple & fast).
    """
    lines = []
    for line in text.splitlines():
        hash_idx = line.find("#")
        if hash_idx != -1:
            line = line[:hash_idx]
        lines.append(line)
    no_comments = "".join(lines)
    return re.sub(r"\s+", "", no_comments)

# %%
# ------------------ Embedding long texts with chunking ------------------ #
def chunk_by_tokens(text: str, tokenizer, max_tokens: int, stride: int) -> List[str]:
    """
    Split `text` into overlapping chunks by tokenizer tokens, then decode each
    chunk back to text for SentenceTransformer.encode.
    """
    # Tokenize once (no specials) then slice token ids.
    toks = tokenizer.encode(text, add_special_tokens=False)
    n = len(toks)
    if n == 0:
        return [""]  # keep shape consistent

    chunks = []
    i = 0
    while i < n:
        window = toks[i : i + max_tokens]
        chunk_text = tokenizer.decode(window, skip_special_tokens=True, clean_up_tokenization_spaces=True)
        chunks.append(chunk_text)
        if i + max_tokens >= n:
            break
        i += max(max_tokens - stride, 1)
    return chunks

# %%
@torch.no_grad()
def embed_long_text(model: SentenceTransformer, text: str, max_tokens: int = 384, stride: int = 64) -> torch.Tensor:
    """
    Embed long text by averaging L2-normalized embeddings over token-based chunks.
    """
    tokenizer = model.tokenizer
    chunks = chunk_by_tokens(text, tokenizer, max_tokens=max_tokens, stride=stride)
    # Encode chunks -> normalized embeddings (SentenceTransformer returns normalized if normalize_embeddings=True is set)
    # We’ll explicitly normalize after.
    embs = model.encode(
        chunks,
        batch_size=8,
        convert_to_tensor=True,
        show_progress_bar=False,
        normalize_embeddings=False,
    )
    # L2-normalize each chunk vector
    embs = torch.nn.functional.normalize(embs, p=2, dim=1)
    # Average then normalize again
    mean_emb = embs.mean(dim=0, keepdim=True)
    mean_emb = torch.nn.functional.normalize(mean_emb, p=2, dim=1)
    return mean_emb.squeeze(0)  # shape: (d,)

# %%
def cosine_similarity(a: torch.Tensor, b: torch.Tensor) -> float:
    return torch.nn.functional.cosine_similarity(a.unsqueeze(0), b.unsqueeze(0)).item()

# %%
def read_csv_file(file_name: str) -> pd.DataFrame:
    if "__file__" in globals():
        base_dir = Path(__file__).resolve().parent
    else:
        base_dir = Path.cwd()

    csv_path = base_dir / file_name

    print(f"📄 CSV path: {csv_path}")
    print(f"🔍 Trying to read: {csv_path.resolve()}")

    if not csv_path.exists():
        raise FileNotFoundError(f"❌ CSV file not found: {csv_path}")

    try:
        df = pd.read_csv(csv_path)
        print(f"✅ Loaded CSV with {len(df)} rows × {len(df.columns)} columns.")
    except Exception as e:
        raise RuntimeError(f"Failed to read CSV: {e}")

    return df

# %%
df_decompiled_syntax_errors = read_csv_file('../dataset/decompiled_syntax_errors.csv')
# Out:
# 📄 CSV path: /home/mxs220189/pylingual_collaboration/pylingual_download/code/utils/../dataset/decompiled_syntax_errors.csv
# 🔍 Trying to read: /home/mxs220189/pylingual_collaboration/pylingual_download/code/dataset/decompiled_syntax_errors.csv
# ✅ Loaded CSV with 383 rows × 6 columns.

# %%
results = []

print("=" * 80)
print("🧩 Starting decompiled file comparison")
print("=" * 80)

total_rows = len(df_decompiled_syntax_errors)
print(f"Total records to process: {total_rows}\n")

    # Load model (CPU by default; will use GPU if available & torch detects it)
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

print(f"Model: {model}")
for idx, row in df_decompiled_syntax_errors.iterrows():
    file_hash = row["file_hash"]
    file_name = row["file"]
    raw_name = file_name.split(".")[0].replace("decompiled_", "")
    missing = False
    # Paths
    path1 = Path(f"../results/experiment_outputs/20260119T061529Z/7513fc1ec4f14913978152d2ffe3de37/{file_hash}/syntax_repaired_{file_name}")
    path2 = Path(f"/home/mxs220189/pylingual_collaboration/pypi_downloaded/{file_hash}/{file_name}")
    path3 = Path(f"/home/mxs220189/pylingual_collaboration/pypi_downloaded/{file_hash}/{raw_name}.py")

    print("-" * 80)
    print(f"[{idx+1}/{total_rows}] 🔍 Comparing files for hash: {file_hash}")
    print(f"  📄 File 1   : {path1.name}")
    print(f"  📄 File 2   : {path2.name}")
    print(f"  📄 File 3   : {path3.name}")

    for fp in (path1, path2, path3):
        if not Path(fp).is_file():
            missing = True

    if missing:
        print(f"⚠️ One or more files are missing. Skipping this record.")
        
        continue
    # Load & (optionally) preprocess
    def prep(path: Path) -> str:
        text = read_text(path)
        return strip_comments_and_whitespace(text)

    s1 = prep(path1)
    s2 = prep(path2)
    s3 = prep(path3)

    # Embed (with chunking for long files)
    e1 = embed_long_text(model, s1, max_tokens=512, stride=128)
    e2 = embed_long_text(model, s2, max_tokens=512, stride=128)
    e3 = embed_long_text(model, s3, max_tokens=512, stride=128)

    # Cosine similarity & distance
    sim_31 = cosine_similarity(e3, e1)
    sim_32 = cosine_similarity(e3, e2)
    dist_32 = 1.0 - sim_32
    dist_31 = 1.0 - sim_31
    print(f"Cosine similarity (file2 vs file1): {sim_32:.6f}  | distance: {dist_32:.6f}")
    print(f"Cosine similarity (file3 vs file1): {sim_31:.6f}  | distance: {dist_31:.6f}")

    results.append({
        "file_hash": file_hash,
        "decompiled_file_name": file_name,
        "raw_file_name": path3.name,
        "d_lookup_vs_decompiled_similarity": sim_32,
        "d_lookup_vs_repaired_similarity": sim_31,
        "d_lookup_vs_decompiled_distance": dist_32,
        "d_lookup_vs_repaired_distance": dist_31,
    })

    print("-" * 80)

    # Uncomment to test only one iteration
    # break

# --- Convert results to DataFrame ---
results_df = pd.DataFrame(results)
print("\n" + "=" * 80)
print("🏁 Finished processing all decompiled file comparisons.")
print("=" * 80)

print("\n📊 Results summary:")
print(results_df.head())
# Out:
# ================================================================================
# 🧩 Starting decompiled file comparison
# ================================================================================
# Total records to process: 383
# Token indices sequence length is longer than the specified maximum sequence length for this model (7444 > 256). Running this sequence through the model will result in indexing errors
# Model: SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False, 'architecture': 'BertModel'})
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )
# --------------------------------------------------------------------------------
# [1/383] 🔍 Comparing files for hash: 025bcf101990c51854d7caa7c53055cdd6e9119e6c5e1764245bcc37ecb1ae92f73c434a962f41411729e6b5a722479e7c5736b316c6f007328524c6bd0f2531
#   📄 File 1   : syntax_repaired_decompiled_jvccommands.cpython-312.py
#   📄 File 2   : decompiled_jvccommands.cpython-312.py
#   📄 File 3   : jvccommands.py
# Cosine similarity (file2 vs file1): 0.965605  | distance: 0.034395
# Cosine similarity (file3 vs file1): 0.965962  | distance: 0.034038
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [2/383] 🔍 Comparing files for hash: 008769cfa97d59dfa51e62b706c58395c46bc887a981999499f691e1b8e3d72b11f4cc31c12f4b236a60333d7f2c4f54906ad5bef214fbe0b385345efe94063d
#   📄 File 1   : syntax_repaired_decompiled_NISQA_model.cpython-312.py
#   📄 File 2   : decompiled_NISQA_model.cpython-312.py
#   📄 File 3   : NISQA_model.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [3/383] 🔍 Comparing files for hash: 0021a4762616818e8d4132c6c47a120fa08d8c5fa099382ae4fa21f4b418b33ff0fa26b8b85f9f6437cef7ef4b97b54b1ee70e824cf50bad14e41739f370a500
#   📄 File 1   : syntax_repaired_decompiled_feature_node_universes.cpython-312.py
#   📄 File 2   : decompiled_feature_node_universes.cpython-312.py
#   📄 File 3   : feature_node_universes.py
# Cosine similarity (file2 vs file1): 0.785229  | distance: 0.214771
# Cosine similarity (file3 vs file1): 0.755453  | distance: 0.244547
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [4/383] 🔍 Comparing files for hash: 00c778a21a451602c67e92625cfbad1c5ecd17c94079426d1b2919595579c1d32d9673d2134f9c61a80a321e74b621853385494f07415bfbca3bc0901223badf
#   📄 File 1   : syntax_repaired_decompiled_icl_prompt_template.cpython-312.py
#   📄 File 2   : decompiled_icl_prompt_template.cpython-312.py
#   📄 File 3   : icl_prompt_template.py
# Cosine similarity (file2 vs file1): 0.974923  | distance: 0.025077
# Cosine similarity (file3 vs file1): 0.974923  | distance: 0.025077
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [5/383] 🔍 Comparing files for hash: 008c16378fbd7120241739f31e6c167ed73c7d44255c208fd4b4c4922d421731dddad0727cb4d8e114a41f56296185fd0a4f0462c7e7d4448b3fcff8a17615ca
#   📄 File 1   : syntax_repaired_decompiled_bier_template.cpython-312.py
#   📄 File 2   : decompiled_bier_template.cpython-312.py
#   📄 File 3   : bier_template.py
# Cosine similarity (file2 vs file1): 0.951420  | distance: 0.048580
# Cosine similarity (file3 vs file1): 0.951358  | distance: 0.048642
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [6/383] 🔍 Comparing files for hash: 009d50defcb40f008c3e2289e85b2d2bc74bd2f06b008d45d81b954ce7d0a8a5437ab56c0557bcaa19ab0f17afeef670c5be934d4170cde47d7f61ac548d1128
#   📄 File 1   : syntax_repaired_decompiled_bigone.cpython-312.py
#   📄 File 2   : decompiled_bigone.cpython-312.py
#   📄 File 3   : bigone.py
# Cosine similarity (file2 vs file1): 0.988163  | distance: 0.011837
# Cosine similarity (file3 vs file1): 0.985956  | distance: 0.014044
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [7/383] 🔍 Comparing files for hash: 0253cf135a521e0fc84fa527b09e38ddd53ab7e895a4552633b2af1af079d88a69a2f894a9e3208b6065c162606f805840708d3be0d2048d5f1439866833b15d
#   📄 File 1   : syntax_repaired_decompiled_qupath_reader.cpython-312.py
#   📄 File 2   : decompiled_qupath_reader.cpython-312.py
#   📄 File 3   : qupath_reader.py
# Cosine similarity (file2 vs file1): 0.988519  | distance: 0.011481
# Cosine similarity (file3 vs file1): 0.987596  | distance: 0.012404
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [8/383] 🔍 Comparing files for hash: 00ef84723bf152924c9e2c63d7899bddf958556d0a0583189a0f07dfdeb34eaf1277607e69dec84d9c32b77bf51aa48b8818fdb75c972b8e385513967b9abdb4
#   📄 File 1   : syntax_repaired_decompiled_jira.cpython-312.py
#   📄 File 2   : decompiled_jira.cpython-312.py
#   📄 File 3   : jira.py
# Cosine similarity (file2 vs file1): 0.986857  | distance: 0.013143
# Cosine similarity (file3 vs file1): 0.986857  | distance: 0.013143
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [9/383] 🔍 Comparing files for hash: 001cd58f00fdbcde414b3d787ac1e0a32a8e7954abfdf3dee91851ee3333e6815ff117e845cd5b7c96b14a61a81640f74c3f83551cff978073396bab7751eb1b
#   📄 File 1   : syntax_repaired_decompiled_test_check_amarisoft_stats_log.cpython-312.py
#   📄 File 2   : decompiled_test_check_amarisoft_stats_log.cpython-312.py
#   📄 File 3   : test_check_amarisoft_stats_log.py
# Cosine similarity (file2 vs file1): 0.988515  | distance: 0.011485
# Cosine similarity (file3 vs file1): 0.975304  | distance: 0.024696
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [10/383] 🔍 Comparing files for hash: 01b65e4670e382c820da8140c5b459602c122feff7c1bc9e9809776085a78e46521655f3f0f34f502f8062a71910609ac7c3bb839eca4a4adc5b240d544862e0
#   📄 File 1   : syntax_repaired_decompiled_fmgr_firewall_address6template.cpython-312.py
#   📄 File 2   : decompiled_fmgr_firewall_address6template.cpython-312.py
#   📄 File 3   : fmgr_firewall_address6template.py
# Cosine similarity (file2 vs file1): 0.431318  | distance: 0.568682
# Cosine similarity (file3 vs file1): 0.369249  | distance: 0.630751
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [11/383] 🔍 Comparing files for hash: 0252292835794a65dc77d88941e4a7ea2ae508c13a0c16893fc720b942669fc11b144dc35e2ec0aeebe8b2e5943fb5e88e0e022201ca1f2ccea4b0d14d0a5bb1
#   📄 File 1   : syntax_repaired_decompiled_MusicHelper.cpython-312.py
#   📄 File 2   : decompiled_MusicHelper.cpython-312.py
#   📄 File 3   : MusicHelper.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [12/383] 🔍 Comparing files for hash: 02b48494e86b973d49018fba550dad02e443b6c8e7831ddae598e811f02c85fbeb72a2f8b478ae0876f7ce16f97cdf6f2a3d20532f74ebed06648e4c2c08fc33
#   📄 File 1   : syntax_repaired_decompiled_kubernetes_cluster.cpython-312.py
#   📄 File 2   : decompiled_kubernetes_cluster.cpython-312.py
#   📄 File 3   : kubernetes_cluster.py
# Cosine similarity (file2 vs file1): 0.984921  | distance: 0.015079
# Cosine similarity (file3 vs file1): 0.995437  | distance: 0.004563
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [13/383] 🔍 Comparing files for hash: 0049b3e8bb53f8429af08ace48e8ec78642c1257a1dcb9cbae8c94c04b0a2541a76a96f044346b6cf16f90414ebeaa5a8af2ccb37099816c4a8f958a40912656
#   📄 File 1   : syntax_repaired_decompiled_preparer.cpython-312.py
#   📄 File 2   : decompiled_preparer.cpython-312.py
#   📄 File 3   : preparer.py
# Cosine similarity (file2 vs file1): 0.989711  | distance: 0.010289
# Cosine similarity (file3 vs file1): 0.990741  | distance: 0.009259
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [14/383] 🔍 Comparing files for hash: 00c4dccf9d7f21846040a3abe4c9e1fee71350407818ac7bd055aefb9e04bef04410868d65518571d74930f98d995cb5783fc7b58a88d59b5a352f70ba16bd58
#   📄 File 1   : syntax_repaired_decompiled_threads.cpython-312.py
#   📄 File 2   : decompiled_threads.cpython-312.py
#   📄 File 3   : threads.py
# Cosine similarity (file2 vs file1): 0.993315  | distance: 0.006685
# Cosine similarity (file3 vs file1): 0.993472  | distance: 0.006528
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [15/383] 🔍 Comparing files for hash: 00691fdb5e97d9583b08acdbc20f859bd428a87ba30a212b0100ca676e87a53a74e1298b265e7312165aba9498f35429eaa1eef3d3844126b934b5a650b747d3
#   📄 File 1   : syntax_repaired_decompiled_get_contest_codechef.cpython-312.py
#   📄 File 2   : decompiled_get_contest_codechef.cpython-312.py
#   📄 File 3   : get_contest_codechef.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [16/383] 🔍 Comparing files for hash: 02b0709d4e9c54728cf6f05828668c049c12c4c620f69ba9526351ca64d2fc52654678be89a4244a984bab3e99553f0813ccfa9846e37d4dcfa7083b08f5c87c
#   📄 File 1   : syntax_repaired_decompiled_exmo.cpython-312.py
#   📄 File 2   : decompiled_exmo.cpython-312.py
#   📄 File 3   : exmo.py
# Cosine similarity (file2 vs file1): 0.989045  | distance: 0.010955
# Cosine similarity (file3 vs file1): 0.989284  | distance: 0.010716
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [17/383] 🔍 Comparing files for hash: 011cf3365f18329fcbac4bf38f7c0c69faa94fbed5689c19a2b162644034d9702c2669fd005836f7adf60146d7092bb9139d7006c7b00df8bbc91f0fbc31b19d
#   📄 File 1   : syntax_repaired_decompiled_climate_mode.cpython-312.py
#   📄 File 2   : decompiled_climate_mode.cpython-312.py
#   📄 File 3   : climate_mode.py
# Cosine similarity (file2 vs file1): 0.967312  | distance: 0.032688
# Cosine similarity (file3 vs file1): 0.990893  | distance: 0.009107
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [18/383] 🔍 Comparing files for hash: 00109c98fab299db82ab241c129b10ef710efb357475b2805018f5936d9bf0f980b761a39145ba20b4021c3e65681981116d4637c0cdaeb7cf8ccb06d4794de5
#   📄 File 1   : syntax_repaired_decompiled_region_network_endpoint_group.cpython-312.py
#   📄 File 2   : decompiled_region_network_endpoint_group.cpython-312.py
#   📄 File 3   : region_network_endpoint_group.py
# Cosine similarity (file2 vs file1): 0.978119  | distance: 0.021881
# Cosine similarity (file3 vs file1): 0.982870  | distance: 0.017130
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [19/383] 🔍 Comparing files for hash: 024a124140f32a4744f9f579f094d7e4dd8b09b269b9c333b38d84dcdda4ff8482c6e823b05b4f70aa030193f487b8390d44065e27fc1829e093cec037667b11
#   📄 File 1   : syntax_repaired_decompiled_bitrue.cpython-312.py
#   📄 File 2   : decompiled_bitrue.cpython-312.py
#   📄 File 3   : bitrue.py
# Cosine similarity (file2 vs file1): 0.980303  | distance: 0.019697
# Cosine similarity (file3 vs file1): 0.975507  | distance: 0.024493
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [20/383] 🔍 Comparing files for hash: 023de8759614bdac6c86cc97a7adfb135f228ea69be5e9c7d300d1566cf082efdf8466828cac08e8118a38e1b99f7c8ed228955ad964e8401f86109dabf9e2f7
#   📄 File 1   : syntax_repaired_decompiled_pnmtdparser.cpython-312.py
#   📄 File 2   : decompiled_pnmtdparser.cpython-312.py
#   📄 File 3   : pnmtdparser.py
# Cosine similarity (file2 vs file1): 0.972307  | distance: 0.027693
# Cosine similarity (file3 vs file1): 0.972753  | distance: 0.027247
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [21/383] 🔍 Comparing files for hash: 00a822978812f5256ac17cbf5e6a21408cc175cc352fcdde78e29d2280ce4406c20434452972f3fb31378df66d06425de7b73db5d0d50ecd7c801e1855764d8b
#   📄 File 1   : syntax_repaired_decompiled_display_on_jupyter.cpython-312.py
#   📄 File 2   : decompiled_display_on_jupyter.cpython-312.py
#   📄 File 3   : display_on_jupyter.py
# Cosine similarity (file2 vs file1): 0.536411  | distance: 0.463589
# Cosine similarity (file3 vs file1): 0.536411  | distance: 0.463589
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [22/383] 🔍 Comparing files for hash: 0282c7bfb1d156f990892a3f93ef860f74aeeba5be4a58a26492488142fe0b3862c54cb5f865755d677aedbd9b07fe1f69866f1330fd72f525710268fe9f2203
#   📄 File 1   : syntax_repaired_decompiled_FSPGrowth.cpython-312.py
#   📄 File 2   : decompiled_FSPGrowth.cpython-312.py
#   📄 File 3   : FSPGrowth.py
# Cosine similarity (file2 vs file1): 0.941743  | distance: 0.058257
# Cosine similarity (file3 vs file1): 0.940230  | distance: 0.059770
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [23/383] 🔍 Comparing files for hash: 01cdb36d201ef586742b3df349a5fd450cc469010fe4e2a4c8d012c19fa2e27f18ae18625d6569af8780354c4019cc49c0dfcbf3fceaffa94f7b8e431fd1a678
#   📄 File 1   : syntax_repaired_decompiled_test_scale_to_zero_to_one.cpython-312.py
#   📄 File 2   : decompiled_test_scale_to_zero_to_one.cpython-312.py
#   📄 File 3   : test_scale_to_zero_to_one.py
# Cosine similarity (file2 vs file1): 0.982487  | distance: 0.017513
# Cosine similarity (file3 vs file1): 0.981672  | distance: 0.018328
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [24/383] 🔍 Comparing files for hash: 022d1ab7c3a4d7bb7791101cde3b8eb7acb7e8241c26df70585201f2442523bf6ba1c81e67bcab38abb535b28201ec139906df17784d0685d97b8bb540a12c09
#   📄 File 1   : syntax_repaired_decompiled_wiliot_tester_tag_test.cpython-312.py
#   📄 File 2   : decompiled_wiliot_tester_tag_test.cpython-312.py
#   📄 File 3   : wiliot_tester_tag_test.py
# Cosine similarity (file2 vs file1): 0.978679  | distance: 0.021321
# Cosine similarity (file3 vs file1): 0.977432  | distance: 0.022568
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [25/383] 🔍 Comparing files for hash: 013c228ec0376b6d18092d0629bc25e36e85491a45d2071562f3c80a66f183dec8bbec1157099222a1bbd0f781fa74938a88f414347f9479725d9253be7e943d
#   📄 File 1   : syntax_repaired_decompiled_spoke.cpython-312.py
#   📄 File 2   : decompiled_spoke.cpython-312.py
#   📄 File 3   : spoke.py
# Cosine similarity (file2 vs file1): 0.980683  | distance: 0.019317
# Cosine similarity (file3 vs file1): 0.977967  | distance: 0.022033
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [26/383] 🔍 Comparing files for hash: 026aee4689eac196dc3e86e2c2f56347553968d4f250f7d8e106217c1b2139641f857d878075e61a7445615f62e7162678e31e6753dbac739bbdb13d8e6e141f
#   📄 File 1   : syntax_repaired_decompiled_test_middleware.cpython-312.py
#   📄 File 2   : decompiled_test_middleware.cpython-312.py
#   📄 File 3   : test_middleware.py
# Cosine similarity (file2 vs file1): 0.996895  | distance: 0.003105
# Cosine similarity (file3 vs file1): 0.994406  | distance: 0.005594
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [27/383] 🔍 Comparing files for hash: 01b3c8df4486bdad3899543ab10b566277b6fc1e0b597f8a494746e69ab1651cd072aa1e417e8108f8a712642227a4dd62be348b457a09683c998199401d20c3
#   📄 File 1   : syntax_repaired_decompiled_bank_applications_idp_api.cpython-312.py
#   📄 File 2   : decompiled_bank_applications_idp_api.cpython-312.py
#   📄 File 3   : bank_applications_idp_api.py
# Cosine similarity (file2 vs file1): 0.919467  | distance: 0.080533
# Cosine similarity (file3 vs file1): 0.920415  | distance: 0.079585
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [28/383] 🔍 Comparing files for hash: 01a61df33c4a5683638cad8430361840bb41916728994284d50ba0beb88bcca7c428f30399b6f5d3daf0a139445e22409299c7e3f6975d3040b9bbc5db02fac7
#   📄 File 1   : syntax_repaired_decompiled_ctfs.cpython-312.py
#   📄 File 2   : decompiled_ctfs.cpython-312.py
#   📄 File 3   : ctfs.py
# Cosine similarity (file2 vs file1): 0.991204  | distance: 0.008796
# Cosine similarity (file3 vs file1): 0.984699  | distance: 0.015301
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [29/383] 🔍 Comparing files for hash: 0102225e79ca17472083bc3328065ae13eca36f441a897484535d6dced8bb03824b8d4e7bf615799ab3091212ba7525e3384532a01c93cd8c4f4c60e345dc858
#   📄 File 1   : syntax_repaired_decompiled_test_reporter.cpython-312.py
#   📄 File 2   : decompiled_test_reporter.cpython-312.py
#   📄 File 3   : test_reporter.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [30/383] 🔍 Comparing files for hash: 02c403a767bc73fa383e225b7d6eb521ada8efa2c73734db90b2e4446503e29dcb2850bf19b184d76ac95e3886f9a66310a5a7a7d610fd14cd39a8b04c9458d0
#   📄 File 1   : syntax_repaired_decompiled_get_disk.cpython-312.py
#   📄 File 2   : decompiled_get_disk.cpython-312.py
#   📄 File 3   : get_disk.py
# Cosine similarity (file2 vs file1): 0.980636  | distance: 0.019364
# Cosine similarity (file3 vs file1): 0.980687  | distance: 0.019313
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [31/383] 🔍 Comparing files for hash: 028027f194d4af1798cfe1fd295ce231e05fd348ebb5c62456098ee5432159c3b44e595d927f570e23946c2fc6080fe43cda82310f3133fb593e0389f0cc5a52
#   📄 File 1   : syntax_repaired_decompiled_no_tears.cpython-312.py
#   📄 File 2   : decompiled_no_tears.cpython-312.py
#   📄 File 3   : no_tears.py
# Cosine similarity (file2 vs file1): 0.938030  | distance: 0.061970
# Cosine similarity (file3 vs file1): 0.938523  | distance: 0.061477
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [32/383] 🔍 Comparing files for hash: 00e6dac93bc153403541045d71c81637c21b5db4da47721343096e04e4d912ec8384a0311696fe787966acd75b9c7a6813182096c724de76d5aa364e5ff81a91
#   📄 File 1   : syntax_repaired_decompiled_run_config_utils.cpython-312.py
#   📄 File 2   : decompiled_run_config_utils.cpython-312.py
#   📄 File 3   : run_config_utils.py
# Cosine similarity (file2 vs file1): 0.977589  | distance: 0.022411
# Cosine similarity (file3 vs file1): 0.987664  | distance: 0.012336
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [33/383] 🔍 Comparing files for hash: 00984453fe18b5717591547c4b1b3177892dc6a6828715f4ac0f199691d1e3756ebb0094b44c7886ce141378d6d421dc0721f61b435c2fd4b8899c52b4db1486
#   📄 File 1   : syntax_repaired_decompiled_animation_complete.cpython-312.py
#   📄 File 2   : decompiled_animation_complete.cpython-312.py
#   📄 File 3   : animation_complete.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [34/383] 🔍 Comparing files for hash: 021f2d5a9daf458a099a52ff4081dd35a8956fbe48a16fb02a85ad12681542d262ef6d0d05b995a92cf0c817565b4918925ffcd4b4ef92979a13529722a93a48
#   📄 File 1   : syntax_repaired_decompiled_second_hv_secfpn_waymo.cpython-312.py
#   📄 File 2   : decompiled_second_hv_secfpn_waymo.cpython-312.py
#   📄 File 3   : second_hv_secfpn_waymo.py
# Cosine similarity (file2 vs file1): 0.834960  | distance: 0.165040
# Cosine similarity (file3 vs file1): 0.837161  | distance: 0.162839
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [35/383] 🔍 Comparing files for hash: 009cb330b0999c2a5ef507b06b952e7c36f21da0fba88ace2bc6e8dc0276a0fdb05977963572d1626bbf7afca10d691cb8d147a447c18369dacaaeee12f5df6b
#   📄 File 1   : syntax_repaired_decompiled_node_cpu_analyzer.cpython-312.py
#   📄 File 2   : decompiled_node_cpu_analyzer.cpython-312.py
#   📄 File 3   : node_cpu_analyzer.py
# Cosine similarity (file2 vs file1): 0.987303  | distance: 0.012697
# Cosine similarity (file3 vs file1): 0.995103  | distance: 0.004897
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [36/383] 🔍 Comparing files for hash: 0240df9bddd21bf2aa1c5eaf5ef52097eaabf4c4833f4a08d246249c34cc098e9dc030199346cd7773cb3cf32253994711ace4348cb8313290d2b42e170feda5
#   📄 File 1   : syntax_repaired_decompiled_audio_utils.cpython-312.py
#   📄 File 2   : decompiled_audio_utils.cpython-312.py
#   📄 File 3   : audio_utils.py
# Cosine similarity (file2 vs file1): 0.978568  | distance: 0.021432
# Cosine similarity (file3 vs file1): 0.979532  | distance: 0.020468
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [37/383] 🔍 Comparing files for hash: 02ef3e50ae61216135f12e1e34659990989c790315eb0b81362d1572851708e52bee2aafc9bbcc811f3e967f242fd024a0dc7fb18a66116cad5f28e520743a9e
#   📄 File 1   : syntax_repaired_decompiled_config_helper.cpython-312.py
#   📄 File 2   : decompiled_config_helper.cpython-312.py
#   📄 File 3   : config_helper.py
# Cosine similarity (file2 vs file1): 0.991426  | distance: 0.008574
# Cosine similarity (file3 vs file1): 0.986743  | distance: 0.013257
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [38/383] 🔍 Comparing files for hash: 00f99c52c2ac3a4fbff532cbb3d96c891ea3df1dcb8527d7fcd96627aedcf802aa00e4589f2d606ad89ccbf99573e991cda7487cdbcba077fbe06102f1081409
#   📄 File 1   : syntax_repaired_decompiled_cloud_cost_allocator.cpython-312.py
#   📄 File 2   : decompiled_cloud_cost_allocator.cpython-312.py
#   📄 File 3   : cloud_cost_allocator.py
# Cosine similarity (file2 vs file1): 0.997069  | distance: 0.002931
# Cosine similarity (file3 vs file1): 0.996834  | distance: 0.003166
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [39/383] 🔍 Comparing files for hash: 000f936110e4ab1b91d3ac4dd3849cf2287ec0f39dc8080714fc22c71cd76bed788b6f172e0f8ef5c4ee674feb356229f80280c6a745e12c3887d6fce1c5f41c
#   📄 File 1   : syntax_repaired_decompiled_logistic_regression_classifier.cpython-312.py
#   📄 File 2   : decompiled_logistic_regression_classifier.cpython-312.py
#   📄 File 3   : logistic_regression_classifier.py
# Cosine similarity (file2 vs file1): 0.991644  | distance: 0.008356
# Cosine similarity (file3 vs file1): 0.994046  | distance: 0.005954
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [40/383] 🔍 Comparing files for hash: 01b5f168ec0a4072f17ee6a5775328d85ce622ba2765ab1aeaaa60da4beaa592637f77cd37b7508ce7ed16e9d9ce42bba415d28d5233088cc656d4df804e82d5
#   📄 File 1   : syntax_repaired_decompiled_stex.cpython-312.py
#   📄 File 2   : decompiled_stex.cpython-312.py
#   📄 File 3   : stex.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [41/383] 🔍 Comparing files for hash: 024de4b21a4dd360319d39ed295b6126bf6ebbdfecff4dc74360556d5e427b0d4ba13d7f990035f89381d648de2a64eef667241cdaa615f0acfd129d4e4c1e21
#   📄 File 1   : syntax_repaired_decompiled_global_address.cpython-312.py
#   📄 File 2   : decompiled_global_address.cpython-312.py
#   📄 File 3   : global_address.py
# Cosine similarity (file2 vs file1): 0.977091  | distance: 0.022909
# Cosine similarity (file3 vs file1): 0.977757  | distance: 0.022243
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [42/383] 🔍 Comparing files for hash: 02456522d61899c40d36b727d89185287498bd619fde8fc11ab380388157cbda5e7305640c10d632914c9f7a19cc725ee55d5dae7dbe47e2f50b7a5cfa3d1685
#   📄 File 1   : syntax_repaired_decompiled_L.cpython-312.py
#   📄 File 2   : decompiled_L.cpython-312.py
#   📄 File 3   : L.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [43/383] 🔍 Comparing files for hash: 01bafd044993fef87ec458bec89ca3ca3ee69c449a1fabea817703af1c9281b80cd55efccc887629cd5ab410bf176f7bd84ca0ea069fc7e4f03bf2d29b2b615a
#   📄 File 1   : syntax_repaired_decompiled_versioncheck.cpython-312.py
#   📄 File 2   : decompiled_versioncheck.cpython-312.py
#   📄 File 3   : versioncheck.py
# Cosine similarity (file2 vs file1): 0.967880  | distance: 0.032120
# Cosine similarity (file3 vs file1): 0.971009  | distance: 0.028991
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [44/383] 🔍 Comparing files for hash: 00ceb28a258b40b3efe0bc5e6175fa2f8ac9dc0870b72c8391db760fcb08c1d9ad86994364ccda406d999728dcfceb5e66ec1ed5369eda8370e12bb7873a2cc9
#   📄 File 1   : syntax_repaired_decompiled_na_elementsw_initiators.cpython-312.py
#   📄 File 2   : decompiled_na_elementsw_initiators.cpython-312.py
#   📄 File 3   : na_elementsw_initiators.py
# Cosine similarity (file2 vs file1): 0.944027  | distance: 0.055973
# Cosine similarity (file3 vs file1): 0.945211  | distance: 0.054789
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [45/383] 🔍 Comparing files for hash: 016ab140eb555a99135456a9af8b1de305c212898fc90a7f308d299c20dfb2de6d90157c0bef8462cacb1730345eb87f300f121f94611ee1a9c50523c9a68cdc
#   📄 File 1   : syntax_repaired_decompiled_test_resolve.cpython-312.py
#   📄 File 2   : decompiled_test_resolve.cpython-312.py
#   📄 File 3   : test_resolve.py
# Cosine similarity (file2 vs file1): 0.975963  | distance: 0.024037
# Cosine similarity (file3 vs file1): 0.976142  | distance: 0.023858
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [46/383] 🔍 Comparing files for hash: 00d75f5ff1d1bb3fb37e073961132fd083a4e360d588f28fefd495a8fb8ca0fa0e6a686c3b140c61c361e6398570f5203293cec93c7b6d0dfdd10ea48630cb47
#   📄 File 1   : syntax_repaired_decompiled_sdk.cpython-312.py
#   📄 File 2   : decompiled_sdk.cpython-312.py
#   📄 File 3   : sdk.py
# Cosine similarity (file2 vs file1): 0.976659  | distance: 0.023341
# Cosine similarity (file3 vs file1): 0.976578  | distance: 0.023422
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [47/383] 🔍 Comparing files for hash: 02c65df8515c4a061a044d617bf4e4442ab3e0b33f67bae9aabf88bbce1d3a3adbab0503a8dacc7069cdc419826e7ab786958ce9878941b0abd3548d2161041a
#   📄 File 1   : syntax_repaired_decompiled_protocol_loop.cpython-312.py
#   📄 File 2   : decompiled_protocol_loop.cpython-312.py
#   📄 File 3   : protocol_loop.py
# Cosine similarity (file2 vs file1): 0.981391  | distance: 0.018609
# Cosine similarity (file3 vs file1): 0.985131  | distance: 0.014869
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [48/383] 🔍 Comparing files for hash: 02d9551b5d454c525add197179ba0bc989faebe9754ee42ecc2dbcf948e4d1f5a7afa845379236f02a171b09d583277d3a624b1b2696a00e2f863adbd445a45f
#   📄 File 1   : syntax_repaired_decompiled_logentries.cpython-312.py
#   📄 File 2   : decompiled_logentries.cpython-312.py
#   📄 File 3   : logentries.py
# Cosine similarity (file2 vs file1): 0.926220  | distance: 0.073780
# Cosine similarity (file3 vs file1): 0.925809  | distance: 0.074191
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [49/383] 🔍 Comparing files for hash: 004562cc24c77c21914a6e5082f73739aa426dde60949e5f6792c0c16f9079023ad8afbd999e3ec2d189ca99c1d5068949107f4a020bc4090e5027afcdb6b0f2
#   📄 File 1   : syntax_repaired_decompiled_server_schema_change_slack_notifier.cpython-312.py
#   📄 File 2   : decompiled_server_schema_change_slack_notifier.cpython-312.py
#   📄 File 3   : server_schema_change_slack_notifier.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [50/383] 🔍 Comparing files for hash: 02c2a6cedbc9c886fcb1d39e4e4d8231980214225a9dbfbdf89ef39f8768e0a77cdf27338dce1b5f2c56872ab5b2199115d7ed3dd5bfbb8cb7d25c4b62ba131f
#   📄 File 1   : syntax_repaired_decompiled_LogP.cpython-312.py
#   📄 File 2   : decompiled_LogP.cpython-312.py
#   📄 File 3   : LogP.py
# Cosine similarity (file2 vs file1): 0.973805  | distance: 0.026195
# Cosine similarity (file3 vs file1): 0.973075  | distance: 0.026925
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [51/383] 🔍 Comparing files for hash: 01fcc7c72d2a78a88ad18f25b5042f39c9542c6273ee93f2d99ea795b9f3f76225eb3cc2ee866fa39545b1367ca3993227be4f2aefd5fdb87cf5ac7d15e5d9ef
#   📄 File 1   : syntax_repaired_decompiled_log_viewer.cpython-312.py
#   📄 File 2   : decompiled_log_viewer.cpython-312.py
#   📄 File 3   : log_viewer.py
# Cosine similarity (file2 vs file1): 0.996354  | distance: 0.003646
# Cosine similarity (file3 vs file1): 0.997721  | distance: 0.002279
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [52/383] 🔍 Comparing files for hash: 02394b74a14ad8e8217e46b5026f9946ae8cb28894a66288fcd8627201d3416876d2d129b32074ab4d36f1efb2e836f4c34d2910508b744ace36f82f51bcfae9
#   📄 File 1   : syntax_repaired_decompiled_hubio.cpython-312.py
#   📄 File 2   : decompiled_hubio.cpython-312.py
#   📄 File 3   : hubio.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [53/383] 🔍 Comparing files for hash: 0266ccaa14125ca5f0ced2da7f1fa84080b66885c00f51e00bd8b0c86d889b013b61a6d22ec946e531ec393118e8e081f279af8c86597f7b27db159f2899da0e
#   📄 File 1   : syntax_repaired_decompiled_points_sampler.cpython-312.py
#   📄 File 2   : decompiled_points_sampler.cpython-312.py
#   📄 File 3   : points_sampler.py
# Cosine similarity (file2 vs file1): 0.962425  | distance: 0.037575
# Cosine similarity (file3 vs file1): 0.962425  | distance: 0.037575
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [54/383] 🔍 Comparing files for hash: 01ee0df15be540b4b75d8b9a263ba7d951a3d90102c0409db00cede47b0073bd3939137b07694acf00e80fdbcb8ad8bfd4c80ef231233c86050380e34dd92152
#   📄 File 1   : syntax_repaired_decompiled_okta.cpython-312.py
#   📄 File 2   : decompiled_okta.cpython-312.py
#   📄 File 3   : okta.py
# Cosine similarity (file2 vs file1): 0.981300  | distance: 0.018700
# Cosine similarity (file3 vs file1): 0.981334  | distance: 0.018666
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [55/383] 🔍 Comparing files for hash: 000d9fbfb6d6860a21c944ea474c64384f7724c96e88cffeb0e501dd7eb4d33f2a8f38c4f1c05f778a98714f079ffacde2b7dad22fa32ac31c06eae64c54da68
#   📄 File 1   : syntax_repaired_decompiled_test_import_merge_sync.cpython-312.py
#   📄 File 2   : decompiled_test_import_merge_sync.cpython-312.py
#   📄 File 3   : test_import_merge_sync.py
# Cosine similarity (file2 vs file1): 0.933729  | distance: 0.066271
# Cosine similarity (file3 vs file1): 0.926486  | distance: 0.073514
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [56/383] 🔍 Comparing files for hash: 009452ee9d083bed50e2118fe8e09c8bd462f1b595904aa3738160eb18dae09f7618ddc17013862d6c4bc1f0ce42969f1feb7760e0a011f4a61043b0fff6006e
#   📄 File 1   : syntax_repaired_decompiled_func_graph.cpython-312.py
#   📄 File 2   : decompiled_func_graph.cpython-312.py
#   📄 File 3   : func_graph.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [57/383] 🔍 Comparing files for hash: 0132b595b206cb12f7d8d7ef2382ff2e54787600e7350f71769c33af1705c3e206f3aaa7469dc2132262a64e5be96c125abb913cb59007867b618ae3ceb91959
#   📄 File 1   : syntax_repaired_decompiled_labels.cpython-312.py
#   📄 File 2   : decompiled_labels.cpython-312.py
#   📄 File 3   : labels.py
# Cosine similarity (file2 vs file1): 0.907426  | distance: 0.092574
# Cosine similarity (file3 vs file1): 0.908978  | distance: 0.091022
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [58/383] 🔍 Comparing files for hash: 01aae9edd439af0670ba65477cf72f6b63ea8faa69aa121e6968fae85e956f9a53a436090f5a1f6cc83058b282c8735d1d7cf7f9676c9cf9bf4262decdbbce02
#   📄 File 1   : syntax_repaired_decompiled_DamageVulnerability.cpython-312.py
#   📄 File 2   : decompiled_DamageVulnerability.cpython-312.py
#   📄 File 3   : DamageVulnerability.py
# Cosine similarity (file2 vs file1): 0.991548  | distance: 0.008452
# Cosine similarity (file3 vs file1): 0.991413  | distance: 0.008587
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [59/383] 🔍 Comparing files for hash: 022b12eef6b2a8eeab59bc09802d4b54d74943155bd94dc3ce81297caa420294b1dae2146680fbd714ad50dd4d3ef50abb24fc0f9dfd7d94e0b4a5272a1ca753
#   📄 File 1   : syntax_repaired_decompiled_topic_topic_network_gui.cpython-312.py
#   📄 File 2   : decompiled_topic_topic_network_gui.cpython-312.py
#   📄 File 3   : topic_topic_network_gui.py
# Cosine similarity (file2 vs file1): 0.962078  | distance: 0.037922
# Cosine similarity (file3 vs file1): 0.964437  | distance: 0.035563
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [60/383] 🔍 Comparing files for hash: 0187a405c6d095830e50dfc8c679d38c71f8171a78e668363b96024f4095c3ebd17f94c52a3b419c85c0793a8569b771fe470ac69bf6cb3fa7aed573839c5034
#   📄 File 1   : syntax_repaired_decompiled_DemoCentralWidget1.cpython-312.py
#   📄 File 2   : decompiled_DemoCentralWidget1.cpython-312.py
#   📄 File 3   : DemoCentralWidget1.py
# Cosine similarity (file2 vs file1): 0.994989  | distance: 0.005011
# Cosine similarity (file3 vs file1): 0.983071  | distance: 0.016929
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [61/383] 🔍 Comparing files for hash: 00e38b7ad21d2e67f275b86905bbbaf514e9bd00508c191e6e5e4e39336cfa13ac7566d08a6747480e93593867ba7f1edb546847eee08269be6b042bf782d694
#   📄 File 1   : syntax_repaired_decompiled_Interp.cpython-312.py
#   📄 File 2   : decompiled_Interp.cpython-312.py
#   📄 File 3   : Interp.py
# Cosine similarity (file2 vs file1): 0.936105  | distance: 0.063895
# Cosine similarity (file3 vs file1): 0.972641  | distance: 0.027359
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [62/383] 🔍 Comparing files for hash: 017b551968a68ccd950b08e5ff62053c56beff094b0898e4855c251e5bcb6024c2d1a36193ae2a1f1faf8009cef764994640bc8e101f04d23f22b7b2b5d7decd
#   📄 File 1   : syntax_repaired_decompiled_basic_words.cpython-312.py
#   📄 File 2   : decompiled_basic_words.cpython-312.py
#   📄 File 3   : basic_words.py
# Cosine similarity (file2 vs file1): 0.272334  | distance: 0.727666
# Cosine similarity (file3 vs file1): 0.208862  | distance: 0.791138
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [63/383] 🔍 Comparing files for hash: 00adce9caef767c6895c3504ee81ba2eefcb8a5f0aaa1c8451e484a32723141ee366436a9c20e5c1832b88695f9c584d5c307a48ba5057162b413d40d5c6633b
#   📄 File 1   : syntax_repaired_decompiled_filter_design.cpython-312.py
#   📄 File 2   : decompiled_filter_design.cpython-312.py
#   📄 File 3   : filter_design.py
# Cosine similarity (file2 vs file1): 0.930279  | distance: 0.069721
# Cosine similarity (file3 vs file1): 0.930277  | distance: 0.069723
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [64/383] 🔍 Comparing files for hash: 015583cf949990a6d573d5295523342a7d73e7c2045515f99df3039b6508e6018a7e7241279153e28250bc8c4ca978e90b82cff920c46e2d45288e7cc4a99154
#   📄 File 1   : syntax_repaired_decompiled_virtual_network_gateway_connection.cpython-312.py
#   📄 File 2   : decompiled_virtual_network_gateway_connection.cpython-312.py
#   📄 File 3   : virtual_network_gateway_connection.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [65/383] 🔍 Comparing files for hash: 0072a479ce71bc4280bda3d0c4eaf7bc7594076f53dcf988cca6fd9e194f748fe691fa4187701c022187ac3a88c3965971d6ccad67c6d37b95796d4429b23b53
#   📄 File 1   : syntax_repaired_decompiled_backend_pb2.cpython-312.py
#   📄 File 2   : decompiled_backend_pb2.cpython-312.py
#   📄 File 3   : backend_pb2.py
# Cosine similarity (file2 vs file1): 0.961016  | distance: 0.038984
# Cosine similarity (file3 vs file1): 0.946403  | distance: 0.053597
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [66/383] 🔍 Comparing files for hash: 01cec3523daa82718cd5798ac2124db372c98cf4a1d750289d1d78a6b824041ff254ff080d7781e1126068c8f870edeb7d8d3551caed41adc4092fb59e12b111
#   📄 File 1   : syntax_repaired_decompiled_pattern.cpython-312.py
#   📄 File 2   : decompiled_pattern.cpython-312.py
#   📄 File 3   : pattern.py
# Cosine similarity (file2 vs file1): 0.949820  | distance: 0.050180
# Cosine similarity (file3 vs file1): 0.954184  | distance: 0.045816
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [67/383] 🔍 Comparing files for hash: 00a512d9a1368cc7559d9b5f5014e4a19eaa36d9fe6bb9b77595e76d1dd201445f3b4cf6d11ff025fcc8ed23d45156ce62e5227b9d79f28f07e11b135175a5bf
#   📄 File 1   : syntax_repaired_decompiled_dismantle.cpython-312.py
#   📄 File 2   : decompiled_dismantle.cpython-312.py
#   📄 File 3   : dismantle.py
# Cosine similarity (file2 vs file1): 0.963615  | distance: 0.036385
# Cosine similarity (file3 vs file1): 0.962293  | distance: 0.037707
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [68/383] 🔍 Comparing files for hash: 01f964008e9fb4e95c019bc939b15a00be9741ff145ef114320ad323948a1624ff5bb42d4b4b507f92e3420d82105dfb618f54a9fdf0708cb4b38fa062fd7f90
#   📄 File 1   : syntax_repaired_decompiled_gmail.cpython-312.py
#   📄 File 2   : decompiled_gmail.cpython-312.py
#   📄 File 3   : gmail.py
# Cosine similarity (file2 vs file1): 0.975681  | distance: 0.024319
# Cosine similarity (file3 vs file1): 0.982937  | distance: 0.017063
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [69/383] 🔍 Comparing files for hash: 003436e6465bb0fa0e7395c9f5d4334b5b59357adfb7abe01f040bb2b2f3f4f0070c7548be656eddce9d2567e28a2e34d6503ff867ff9389c487453d0602f2ca
#   📄 File 1   : syntax_repaired_decompiled_apk.cpython-312.py
#   📄 File 2   : decompiled_apk.cpython-312.py
#   📄 File 3   : apk.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [70/383] 🔍 Comparing files for hash: 0041c5c7cd584493cfc652de507ebe8e8379284fcbbb8b1365a9253bbc02da0f7e6ee0cdce8f59353ce956656e62bb93fb3230ede1c536917ef5f4d49b438093
#   📄 File 1   : syntax_repaired_decompiled_analyze-dataset-batches.cpython-312.py
#   📄 File 2   : decompiled_analyze-dataset-batches.cpython-312.py
#   📄 File 3   : analyze-dataset-batches.py
# Cosine similarity (file2 vs file1): 0.985027  | distance: 0.014973
# Cosine similarity (file3 vs file1): 0.982005  | distance: 0.017995
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [71/383] 🔍 Comparing files for hash: 014c4f12be08b58ceea8fd8470cded1e5bf0e01ef47be03e22ed935354f838fcc0bcd0dbc642f8ac7d414493292290101ad40eb85cbf87e112702c52f7937a98
#   📄 File 1   : syntax_repaired_decompiled_events_tree.cpython-312.py
#   📄 File 2   : decompiled_events_tree.cpython-312.py
#   📄 File 3   : events_tree.py
# Cosine similarity (file2 vs file1): 0.918625  | distance: 0.081375
# Cosine similarity (file3 vs file1): 0.919193  | distance: 0.080807
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [72/383] 🔍 Comparing files for hash: 01dd4ca9a4443f62c51f1fc37bb6862866e3514875a3ba8c7a0b9c81788937a7298cf4316b826458e1ba3288718ac8a53fa79d8af3a386677a3f3cbe3f787e79
#   📄 File 1   : syntax_repaired_decompiled_stratify_test.cpython-312.py
#   📄 File 2   : decompiled_stratify_test.cpython-312.py
#   📄 File 3   : stratify_test.py
# Cosine similarity (file2 vs file1): 0.982695  | distance: 0.017305
# Cosine similarity (file3 vs file1): 0.982621  | distance: 0.017379
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [73/383] 🔍 Comparing files for hash: 010ae871f45b84d0a7bf5224c1ac7d4906932c8478ff44f0f34d46693f17c9717e03610466f4370dc369c558d581d3a5fb7868ff5cf0e5723fd38331978a5a1c
#   📄 File 1   : syntax_repaired_decompiled_update_languages_request_v_next.cpython-312.py
#   📄 File 2   : decompiled_update_languages_request_v_next.cpython-312.py
#   📄 File 3   : update_languages_request_v_next.py
# Cosine similarity (file2 vs file1): 0.643277  | distance: 0.356723
# Cosine similarity (file3 vs file1): 0.660003  | distance: 0.339997
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [74/383] 🔍 Comparing files for hash: 02eceb611797748b42097f7a1660af6a49bafb0eab7bc6e07d14f63530487922e03fbc92ae059116621b2bffefc537691c9acd24c2219eb4b450195758b14300
#   📄 File 1   : syntax_repaired_decompiled_test_ls_disk.cpython-312.py
#   📄 File 2   : decompiled_test_ls_disk.cpython-312.py
#   📄 File 3   : test_ls_disk.py
# Cosine similarity (file2 vs file1): 0.979138  | distance: 0.020862
# Cosine similarity (file3 vs file1): 0.978001  | distance: 0.021999
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [75/383] 🔍 Comparing files for hash: 0212e98177af9ec6a22c9d8d1d1a61c87a2f8c9c2315fa688e77a099d52dd7e817f16d1d34f836c4fa46f6a41bf2f6f1065176e8a0bf59bc57544007444eec22
#   📄 File 1   : syntax_repaired_decompiled_normalized_project_revision.cpython-312.py
#   📄 File 2   : decompiled_normalized_project_revision.cpython-312.py
#   📄 File 3   : normalized_project_revision.py
# Cosine similarity (file2 vs file1): 0.560107  | distance: 0.439893
# Cosine similarity (file3 vs file1): 0.560107  | distance: 0.439893
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [76/383] 🔍 Comparing files for hash: 02bf6ed01dda9ed8a1b55e1c208de53f2419a8f1432011f4dde28d14423b99bab5aec8a2314f38465b8daaf4d8dbd1a1a8b16edb66babdff359d74e65bba727a
#   📄 File 1   : syntax_repaired_decompiled_missing.cpython-312.py
#   📄 File 2   : decompiled_missing.cpython-312.py
#   📄 File 3   : missing.py
# Cosine similarity (file2 vs file1): 0.932243  | distance: 0.067757
# Cosine similarity (file3 vs file1): 0.930274  | distance: 0.069726
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [77/383] 🔍 Comparing files for hash: 02054e3bb0872d89f342eeddc0e380c9793a4b09a23eba269df5e8811bc572159ddbf71616d94cb22b48edb7c76854bb2817257e2bbe76637205d7fe044acc88
#   📄 File 1   : syntax_repaired_decompiled_lineage.cpython-312.py
#   📄 File 2   : decompiled_lineage.cpython-312.py
#   📄 File 3   : lineage.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [78/383] 🔍 Comparing files for hash: 006a1f9f4b7a46f9e107f72c36ce70b5bb16173ab40d7950e588ac27aa7e568388d4b417bcab8b4318146e8dd20a15f6b494547fa71e9a93af6c49ba0443e738
#   📄 File 1   : syntax_repaired_decompiled_file_api.cpython-312.py
#   📄 File 2   : decompiled_file_api.cpython-312.py
#   📄 File 3   : file_api.py
# Cosine similarity (file2 vs file1): 0.944889  | distance: 0.055111
# Cosine similarity (file3 vs file1): 0.946417  | distance: 0.053583
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [79/383] 🔍 Comparing files for hash: 00f16c285587300316a8a65311100e08dd16b619912830d1de8865ea9691e387c8d0c2835ce6ce2dd08bec8a91b705ade7c4d3766bf737e43686ed3bf8194b89
#   📄 File 1   : syntax_repaired_decompiled_web_application_firewall_policy.cpython-312.py
#   📄 File 2   : decompiled_web_application_firewall_policy.cpython-312.py
#   📄 File 3   : web_application_firewall_policy.py
# Cosine similarity (file2 vs file1): 0.979214  | distance: 0.020786
# Cosine similarity (file3 vs file1): 0.978711  | distance: 0.021289
# ...
#   📄 File 1   : syntax_repaired_decompiled_test_api.cpython-312.py
#   📄 File 2   : decompiled_test_api.cpython-312.py
#   📄 File 3   : test_api.py
# Cosine similarity (file2 vs file1): 0.395582  | distance: 0.604418
# Cosine similarity (file3 vs file1): 0.390282  | distance: 0.609718
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [360/383] 🔍 Comparing files for hash: 01f2704e17d88f64acc1c40c38b853db203ecbc34c016cb0119a0acf600a03d60dd3711bd33b8d15f33e6160958480b4cb72c90673f6c359757bf04927d3f024
#   📄 File 1   : syntax_repaired_decompiled_agent_pool.cpython-312.py
#   📄 File 2   : decompiled_agent_pool.cpython-312.py
#   📄 File 3   : agent_pool.py
# Cosine similarity (file2 vs file1): 0.886161  | distance: 0.113839
# Cosine similarity (file3 vs file1): 0.902493  | distance: 0.097507
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [361/383] 🔍 Comparing files for hash: 01bfc1ca886147716dd1bd84384f290f90c1487f48c2a7ea9a4f109534a6e4f0d6818869e0b4b6e8ad96376a92e597846c0d70c568926cb1f25e69ecbaa367f1
#   📄 File 1   : syntax_repaired_decompiled_mercado.cpython-312.py
#   📄 File 2   : decompiled_mercado.cpython-312.py
#   📄 File 3   : mercado.py
# Cosine similarity (file2 vs file1): 0.970674  | distance: 0.029326
# Cosine similarity (file3 vs file1): 0.969635  | distance: 0.030365
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [362/383] 🔍 Comparing files for hash: 029eea43f4e43f9e06bb68b21e7e6a832676a9404ce6c1780f8e15fc0d61a85e79f4515c56c3ce83dbd454a84e59e6267c21229487fba6e1a136c6fd71dab17a
#   📄 File 1   : syntax_repaired_decompiled_security_rule.cpython-312.py
#   📄 File 2   : decompiled_security_rule.cpython-312.py
#   📄 File 3   : security_rule.py
# Cosine similarity (file2 vs file1): 0.975556  | distance: 0.024444
# Cosine similarity (file3 vs file1): 0.976133  | distance: 0.023867
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [363/383] 🔍 Comparing files for hash: 020020f0d5e0eb5bdb36051889e9fde580daaa6f6ad5014ea85d4e4ae89d7202312e0324272bb50d8a71288fba171902e7c7b75e1d98d1b399a221c3d4d05fbe
#   📄 File 1   : syntax_repaired_decompiled_fields.cpython-312.py
#   📄 File 2   : decompiled_fields.cpython-312.py
#   📄 File 3   : fields.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [364/383] 🔍 Comparing files for hash: 000d345bdf406b31ab90df695f832e31e4509d357faa4693da76618bd1231a8d39b48d00b4a69622dfce9c92a9df2048272cf03e0598500278a31fc80a74b9ba
#   📄 File 1   : syntax_repaired_decompiled_bitmex.cpython-312.py
#   📄 File 2   : decompiled_bitmex.cpython-312.py
#   📄 File 3   : bitmex.py
# Cosine similarity (file2 vs file1): 0.978194  | distance: 0.021806
# Cosine similarity (file3 vs file1): 0.977755  | distance: 0.022245
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [365/383] 🔍 Comparing files for hash: 0159c03c07f631ffe3e292b1ee02305ee179428499437d3669e6b1d7a33552f61d01a47073dc0ec906fea3494361b73510efe78e0477864c69da840d75aca604
#   📄 File 1   : syntax_repaired_decompiled_functions.cpython-312.py
#   📄 File 2   : decompiled_functions.cpython-312.py
#   📄 File 3   : functions.py
# Cosine similarity (file2 vs file1): 0.479335  | distance: 0.520665
# Cosine similarity (file3 vs file1): 0.478431  | distance: 0.521569
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [366/383] 🔍 Comparing files for hash: 005815b30d3dec1f873c4c4213947074d9e7004cdbd2ad56ef9dd757113bf395cbf0c247d00f53dbf218965a6d038acc31df92d46aaf2188a24260b7675861b4
#   📄 File 1   : syntax_repaired_decompiled_indexer.cpython-312.py
#   📄 File 2   : decompiled_indexer.cpython-312.py
#   📄 File 3   : indexer.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [367/383] 🔍 Comparing files for hash: 01fc1feafc263f769c5eaad8fbdae170cc12fb89bd428ea620a9af99ea483252c452b19e2bfce4dc74cc2d71035758b556747512cbbdfc39c35a981f3bf998ce
#   📄 File 1   : syntax_repaired_decompiled_files.cpython-312.py
#   📄 File 2   : decompiled_files.cpython-312.py
#   📄 File 3   : files.py
# Cosine similarity (file2 vs file1): 0.582626  | distance: 0.417374
# Cosine similarity (file3 vs file1): 0.577298  | distance: 0.422702
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [368/383] 🔍 Comparing files for hash: 003c4866d18ebbacdb8ef5a6cc1eb86770dccb9abb546d0e57767bcc2cf2357c7e5bbaea0ac1fcf70583c1a584300e82b40a0f272b4a58bfbac18ffea9f151c5
#   📄 File 1   : syntax_repaired_decompiled_vpn_gateway.cpython-312.py
#   📄 File 2   : decompiled_vpn_gateway.cpython-312.py
#   📄 File 3   : vpn_gateway.py
# Cosine similarity (file2 vs file1): 0.965077  | distance: 0.034923
# Cosine similarity (file3 vs file1): 0.964263  | distance: 0.035737
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [369/383] 🔍 Comparing files for hash: 0091bb7fbf725384f9bba69d1f5f901ae24adcaae454d78c2ca37c6902c37c1a272bd35d424dfbbe48c4664eab5786e0eb5862a875067fa5fa8482771ce1276e
#   📄 File 1   : syntax_repaired_decompiled_cluster.cpython-312.py
#   📄 File 2   : decompiled_cluster.cpython-312.py
#   📄 File 3   : cluster.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [370/383] 🔍 Comparing files for hash: 008ffbeda19d412e39b24dc2451ff1dde6a082537595bd1b1218e1054f24f17f5f2fdce38b84731867c5f2f76bdf12fa1c68f34b2b047731d322c413eb41ee02
#   📄 File 1   : syntax_repaired_decompiled_environment.cpython-312.py
#   📄 File 2   : decompiled_environment.cpython-312.py
#   📄 File 3   : environment.py
# Cosine similarity (file2 vs file1): 0.449977  | distance: 0.550023
# Cosine similarity (file3 vs file1): 0.456901  | distance: 0.543099
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [371/383] 🔍 Comparing files for hash: 017987df7ef46392baa7aa7dca30653a84775f37ae78863c6f7e9f24ee7d904a19187a30e6c92f477b58d08b9d5e26c4786c9e1f04800f0d4b278808647263e5
#   📄 File 1   : syntax_repaired_decompiled_enums.cpython-312.py
#   📄 File 2   : decompiled_enums.cpython-312.py
#   📄 File 3   : enums.py
# Cosine similarity (file2 vs file1): 0.241227  | distance: 0.758773
# Cosine similarity (file3 vs file1): 0.240924  | distance: 0.759076
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [372/383] 🔍 Comparing files for hash: 02eeaea0e1a129ebe600cb8069689e07d11d41bf5ad3ed994aec6b6cab03f5dda8a2a8e6357da4302bc638dfcafbae508ae8732888bb9e72bb3668112866df33
#   📄 File 1   : syntax_repaired_decompiled_handlers.cpython-312.py
#   📄 File 2   : decompiled_handlers.cpython-312.py
#   📄 File 3   : handlers.py
# Cosine similarity (file2 vs file1): 0.589068  | distance: 0.410932
# Cosine similarity (file3 vs file1): 0.585070  | distance: 0.414930
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [373/383] 🔍 Comparing files for hash: 007dedfebc213221d99d88b9f3f22444f0bd880a7b233ccf25ce1ae7f0204585f9fbddbd7945438363628535cd67cbc66acfa716b1e43e22686fda8e8903800a
#   📄 File 1   : syntax_repaired_decompiled_models.cpython-312.py
#   📄 File 2   : decompiled_models.cpython-312.py
#   📄 File 3   : models.py
# Cosine similarity (file2 vs file1): 0.588205  | distance: 0.411795
# Cosine similarity (file3 vs file1): 0.589184  | distance: 0.410816
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [374/383] 🔍 Comparing files for hash: 0145e24fa09f153d7b733a8515d6506d77d4e9245cf3229874a835cff3ef4bf7841523195f0258a10636a814f6cfbc4a4d271696d60731bc3c62871f11032851
#   📄 File 1   : syntax_repaired_decompiled_parser.cpython-312.py
#   📄 File 2   : decompiled_parser.cpython-312.py
#   📄 File 3   : parser.py
# Cosine similarity (file2 vs file1): 0.492316  | distance: 0.507684
# Cosine similarity (file3 vs file1): 0.489791  | distance: 0.510209
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [375/383] 🔍 Comparing files for hash: 02baa409eede09d23f92d2c23911f35523e144957c03d3de81e5f23b02b0b56fdab832b61a3d512987e78d63b417bef0b5a29d2ea324018ce9d98ba78930e90e
#   📄 File 1   : syntax_repaired_decompiled_train.cpython-312.py
#   📄 File 2   : decompiled_train.cpython-312.py
#   📄 File 3   : train.py
# Cosine similarity (file2 vs file1): 0.606416  | distance: 0.393584
# Cosine similarity (file3 vs file1): 0.604375  | distance: 0.395625
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [376/383] 🔍 Comparing files for hash: 0198f5507a4d17c35532b6c3d55b5ba83a31c157fccca31c92df17e60cccab650e00ece0454909e5d31fe4713159fa7d3828fdf74b8388615f10e8d26e011371
#   📄 File 1   : syntax_repaired_decompiled_get_virtual_machine.cpython-312.py
#   📄 File 2   : decompiled_get_virtual_machine.cpython-312.py
#   📄 File 3   : get_virtual_machine.py
# Cosine similarity (file2 vs file1): 0.911061  | distance: 0.088939
# Cosine similarity (file3 vs file1): 0.911103  | distance: 0.088897
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [377/383] 🔍 Comparing files for hash: 01854fbf71764ab02565eea2fb1adf06b1d76d73b9e9d2ddf6262c459e5705424eb901e836f2ffcefab481bf24da144ae291a69165dc4c1551943714dd6814c9
#   📄 File 1   : syntax_repaired_decompiled_const.cpython-312.py
#   📄 File 2   : decompiled_const.cpython-312.py
#   📄 File 3   : const.py
# Cosine similarity (file2 vs file1): 0.290017  | distance: 0.709983
# Cosine similarity (file3 vs file1): 0.299795  | distance: 0.700205
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [378/383] 🔍 Comparing files for hash: 0120cb12b320908b79891add531d82afad065f56a044e706f121f2454a04b81b146638e8576fe983e3ddce557f3011734e4c3ef8afd5ef0fdeece912566fa6a8
#   📄 File 1   : syntax_repaired_decompiled_urls.cpython-312.py
#   📄 File 2   : decompiled_urls.cpython-312.py
#   📄 File 3   : urls.py
# Cosine similarity (file2 vs file1): 0.279109  | distance: 0.720891
# Cosine similarity (file3 vs file1): 0.292535  | distance: 0.707465
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [379/383] 🔍 Comparing files for hash: 00dbd7e6a4e3cba0b7aebf59ad0b208e091f87cb851a5895fe7e3641c7031f3d0bc73372987a8ba34cc1c683bf231f0c0b03e12e16c5eb1cb203118871cbe7e3
#   📄 File 1   : syntax_repaired_decompiled_exchange.cpython-312.py
#   📄 File 2   : decompiled_exchange.cpython-312.py
#   📄 File 3   : exchange.py
# Cosine similarity (file2 vs file1): 0.962030  | distance: 0.037970
# Cosine similarity (file3 vs file1): 0.962532  | distance: 0.037468
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [380/383] 🔍 Comparing files for hash: 02439a0892576359290cda6ecdd77983b95e44c55cea5c5d0e5b8c4a0e95dcb84c8549ca2829fe172507fb2d13884547de9f15f0af5261858839949ab736dd6c
#   📄 File 1   : syntax_repaired_decompiled_queries.cpython-312.py
#   📄 File 2   : decompiled_queries.cpython-312.py
#   📄 File 3   : queries.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [381/383] 🔍 Comparing files for hash: 0233993dedeaa9aadddba7824abd009455d1843260b60cc48e3f1169a61e143dfb03232b92c2d4a45f0a4296ffa897ff74b1ec4cba4bd859adc1fccc7e3db478
#   📄 File 1   : syntax_repaired_decompiled_domain.cpython-312.py
#   📄 File 2   : decompiled_domain.cpython-312.py
#   📄 File 3   : domain.py
# ⚠️ One or more files are missing. Skipping this record.
# --------------------------------------------------------------------------------
# [382/383] 🔍 Comparing files for hash: 019e8e6a12df417f798bcb4a0bed9b98cfd93d5fb93bb1be0077cc4c49719e2061abb903c5e3bb10ddf1213d084494b807869f512e873df19c468ba96d514eb3
#   📄 File 1   : syntax_repaired_decompiled_constants.cpython-312.py
#   📄 File 2   : decompiled_constants.cpython-312.py
#   📄 File 3   : constants.py
# Cosine similarity (file2 vs file1): 0.372679  | distance: 0.627321
# Cosine similarity (file3 vs file1): 0.372679  | distance: 0.627321
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [383/383] 🔍 Comparing files for hash: 001709536658c0d399f5f5ae9b6178a0b28b28bddea312df2efb55c804785ada4f7fc3436f1fd63cb9101af46a5a593f82cdc1e01f1e8d7fa405ecdb7cb0addb
#   📄 File 1   : syntax_repaired_decompiled_utils.cpython-312.py
#   📄 File 2   : decompiled_utils.cpython-312.py
#   📄 File 3   : utils.py
# ⚠️ One or more files are missing. Skipping this record.
#
# ================================================================================
# 🏁 Finished processing all decompiled file comparisons.
# ================================================================================
#
# 📊 Results summary:
#                                            file_hash  \
# 0  025bcf101990c51854d7caa7c53055cdd6e9119e6c5e17...
# 1  0021a4762616818e8d4132c6c47a120fa08d8c5fa09938...
# 2  00c778a21a451602c67e92625cfbad1c5ecd17c9407942...
# 3  008c16378fbd7120241739f31e6c167ed73c7d44255c20...
# 4  009d50defcb40f008c3e2289e85b2d2bc74bd2f06b008d...
#
#                                decompiled_file_name  \
# 0             decompiled_jvccommands.cpython-312.py
# 1  decompiled_feature_node_universes.cpython-312.py
# 2     decompiled_icl_prompt_template.cpython-312.py
# 3           decompiled_bier_template.cpython-312.py
# 4                  decompiled_bigone.cpython-312.py
#
#                raw_file_name  d_lookup_vs_decompiled_similarity  \
# 0             jvccommands.py                           0.965605
# 1  feature_node_universes.py                           0.785229
# 2     icl_prompt_template.py                           0.974923
# 3           bier_template.py                           0.951420
# 4                  bigone.py                           0.988163
#
#    d_lookup_vs_repaired_similarity  d_lookup_vs_decompiled_distance  \
# 0                         0.965962                         0.034395
# 1                         0.755453                         0.214771
# 2                         0.974923                         0.025077
# 3                         0.951358                         0.048580
# 4                         0.985956                         0.011837
#
#    d_lookup_vs_repaired_distance
# 0                       0.034038
# 1                       0.244547
# 2                       0.025077
# 3                       0.048642
# 4                       0.014044

# %%
# --- Optional: Save results ---
output_csv = Path("../dataset/decompiled_comparison_results_qwen_34b_enhanced_cosine.csv")
results_df.to_csv(output_csv, index=False)
print(f"\n💾 Results saved to: {output_csv.resolve()}")
# Out:
# 💾 Results saved to: /home/mxs220189/pylingual_collaboration/pylingual_download/code/dataset/decompiled_comparison_results_qwen_34b_enhanced_cosine.csv

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path

def plot_dualcolor_bars_by_index(
    df: pd.DataFrame,
    output_dir: Path | str = "plots",
    col1: str = "d_lookup_vs_decompiled",
    col2: str = "d_lookup_vs_repaired",
    title: str = "Edit Distance per File Index",
    color1: str = "#1f77b4",  # blue
    color2: str = "#ff7f0e",  # orange
    fig_width: float = 16,
    fig_height: float = 8,
    bar_width: float = 0.9,
    overlay_scale: float = 0.7,
    alpha1: float = 0.8,
    alpha2: float = 0.9,
    show: bool = True,
    save: bool = True,
):
    """
    Plot one large bar per file index, divided into two colored layers.

    The wider base bar shows col1 (e.g. decompiled distance),
    and a narrower overlay bar shows col2 (e.g. repaired distance).

    Args:
        df: DataFrame with numeric columns col1 and col2.
        output_dir: Directory to save the plot.
        col1, col2: Column names for comparison.
        title: Plot title.
        color1, color2: Colors for the two metrics.
        fig_width, fig_height: Figure dimensions in inches.
        bar_width: Width of base bars (0–1).
        overlay_scale: Fractional width for overlay bars.
        alpha1, alpha2: Transparency of the bars.
        show, save: Whether to display and/or save the plot.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    if col1 not in df.columns or col2 not in df.columns:
        print(f"❌ Missing one or both columns: {col1}, {col2}")
        print("Available columns:", list(df.columns))
        return

    x = np.arange(len(df))
    vals1 = df[col1].to_numpy()
    vals2 = df[col2].to_numpy()

    fig, ax = plt.subplots(figsize=(fig_width, fig_height))

    # Base (wider) bar
    ax.bar(
        x,
        vals1,
        width=bar_width,
        color=color1,
        alpha=alpha1,
        label=f"{col1} (base)",
        edgecolor="black",
        linewidth=0.5,
    )

    # Overlay (narrower) bar
    ax.bar(
        x,
        vals2,
        width=bar_width * overlay_scale,
        color=color2,
        alpha=alpha2,
        label=f"{col2} (overlay)",
        edgecolor="black",
        linewidth=0.3,
    )

    # Style
    ax.set_xlabel("File Index", fontsize=14)
    ax.set_ylabel("Edit Distance", fontsize=14)
    ax.set_title(title, fontsize=16, pad=12, weight="bold")
    ax.legend(fontsize=12)
    ax.grid(axis="y", linestyle="--", alpha=0.4)
    plt.xticks(fontsize=11)
    plt.yticks(fontsize=11)
    plt.tight_layout()

    if save:
        out_path = output_dir / "edit_distance_dualcolor_large.png"
        plt.savefig(out_path, dpi=250)
        print(f"💾 Saved plot → {out_path.resolve()}")

    if show:
        plt.show()
    else:
        plt.close()

# %%
plot_dualcolor_bars_by_index(
    results_df,
    output_dir="../results/figures",
    col1="d_lookup_vs_decompiled_distance",
    col2="d_lookup_vs_repaired_distance",
    title="Edit Distance Comparison",
    fig_width=20,     # make the figure very wide
    fig_height=10,    # and tall
    bar_width=0.9,    # make bars thick
    overlay_scale=0.75,  # slightly narrower overlay
    show=True
)
# Out:
# 💾 Saved plot → /home/mxs220189/pylingual_collaboration/pylingual_download/code/results/figures/edit_distance_dualcolor_large.png

# %%
# plot_dualcolor_bars_by_index(
#     results_df,
#     output_dir="../results/figures",
#     col1="d_lookup_vs_decompiled_similarity",
#     col2="d_lookup_vs_repaired_similarity",
#     title="Edit Distance Comparison (Wider Bars & Larger Plot)",
#     fig_width=20,     # make the figure very wide
#     fig_height=10,    # and tall
#     bar_width=0.9,    # make bars thick
#     overlay_scale=0.75,  # slightly narrower overlay
#     show=True
# )
