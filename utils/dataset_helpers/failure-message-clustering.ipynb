# %%
from datasets import load_dataset, Dataset
import pandas as pd
import torch
import numpy as np

# %%
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
def read_excels(file_paths):
    data_frames = [pd.read_excel(file) for file in file_paths]
    combined_df = pd.concat(data_frames, ignore_index=True)
    return combined_df

# %%
def read_csvs(file_paths):
    data_frames = [pd.read_csv(file) for file in file_paths]
    combined_df = pd.concat(data_frames, ignore_index=True)
    return combined_df

# %%
read_csv_files = ['../dataset/dataset_summary_failed_case.csv']

# %%
read_files = ['../dataset/dataset_summary_failed_case.xlsx']

# %%
failed_cases_df_initial = read_csvs(read_csv_files)

# %%
failed_cases_df = read_excels(read_files)

# %%
failed_cases_df.head()
# Out:
#                                            file_hash syntactic_error_word  \
# 0  d3204438087d7d924f50237ca1438a01c5d8bf5e26bb23...          SyntaxError
# 1  f131e8b1b384f595ae4976583b055a565560f5f1d70164...          SyntaxError
# 2  410c8bffc380e1f887d96db79780392e309662f3b6e135...          SyntaxError
# 3  46e112f054ecc3b819ca39178321dc01d23be5e49c2151...          SyntaxError
# 4  71ddfa42351aae24b5c2bfe98c77117fd09f683ac3da97...          SyntaxError
#
#                              syntactic_error_message  \
# 0                                      unmatched ')'
# 1  closing parenthesis ']' does not match opening...
# 2        invalid syntax. Perhaps you forgot a comma?
# 3                        too many nested parentheses
# 4  closing parenthesis ']' does not match opening...
#
#                              precessed_error_message  \
# 0                                      unmatched ')'
# 1  closing parenthesis ']' does not match opening...
# 2  invalid whitespace in between expression, math...
# 3                        too many nested parentheses
# 4  closing parenthesis ']' does not match opening...
#
#                          syntactic_error_description
# 0  File "results/experiment_outputs/20251004T0504...
# 1  File "results/experiment_outputs/20251004T0504...
# 2  File "results/experiment_outputs/20251003T1658...
# 3  File "results/experiment_outputs/20251003T0117...
# 4  File "results/experiment_outputs/20251004T0504...

# %%
failed_cases_df_initial.head()
# Out:
#                                            file_hash syntactic_error_word  \
# 0  d3204438087d7d924f50237ca1438a01c5d8bf5e26bb23...          SyntaxError
# 1  f131e8b1b384f595ae4976583b055a565560f5f1d70164...          SyntaxError
# 2  410c8bffc380e1f887d96db79780392e309662f3b6e135...          SyntaxError
# 3  46e112f054ecc3b819ca39178321dc01d23be5e49c2151...          SyntaxError
# 4  71ddfa42351aae24b5c2bfe98c77117fd09f683ac3da97...          SyntaxError
#
#                              syntactic_error_message  \
# 0                                      unmatched ')'
# 1  closing parenthesis ']' does not match opening...
# 2        invalid syntax. Perhaps you forgot a comma?
# 3                        too many nested parentheses
# 4  closing parenthesis ']' does not match opening...
#
#                              precessed_error_message  \
# 0                                      unmatched ')'
# 1  closing parenthesis ']' does not match opening...
# 2        invalid syntax. perhaps you forgot a comma?
# 3                        too many nested parentheses
# 4  closing parenthesis ']' does not match opening...
#
#                          syntactic_error_description
# 0  File "results/experiment_outputs/20251004T0504...
# 1  File "results/experiment_outputs/20251004T0504...
# 2  File "results/experiment_outputs/20251003T1658...
# 3  File "results/experiment_outputs/20251003T0117...
# 4  File "results/experiment_outputs/20251004T0504...

# %%
failed_cases_df_initial = failed_cases_df_initial[failed_cases_df_initial["precessed_error_message"] != "invalid syntax"]

# %%
failed_cases_df_initial = failed_cases_df_initial[failed_cases_df_initial["precessed_error_message"] != "version none is invalid"]
failed_cases_df = failed_cases_df[failed_cases_df["precessed_error_message"] != "version none is invalid"]

# %%
failed_cases_df_initial["precessed_error_message"].to_list()
# Out:
# ["unmatched ')'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'invalid syntax. perhaps you forgot a comma?',
#  'too many nested parentheses',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unterminated string literal',
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  "'(' was never closed",
#  "invalid character '✗'",
#  "expected 'except' or 'finally' block",
#  'unexpected indent',
#  'f-string expression part cannot include a backslash',
#  'f-string: invalid syntax',
#  'too many nested parentheses',
#  'invalid syntax. perhaps you forgot a comma?',
#  'cannot assign to literal',
#  'unterminated string literal',
#  "f-string: single '}' is not allowed",
#  "f-string: expecting a valid expression after '{'",
#  "f-string: expecting '!', or ':', or '}'",
#  'unterminated string literal',
#  "f-string: expecting '}'",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 37",
#  "'[' was never closed",
#  "f-string: expecting a valid expression after '{'",
#  "cannot assign to function call here. maybe you meant '==' instead of '='?",
#  'too many nested parentheses',
#  "f-string: expecting '!', or ':', or '}'",
#  "'{' was never closed",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "'yield' outside function",
#  'unterminated string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'break' outside loop",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "'[' was never closed",
#  'unterminated string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "annotated name 'version_control' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "cannot assign to literal here. maybe you meant '==' instead of '='?",
#  'keyword argument repeated',
#  'invalid syntax. perhaps you forgot a comma?',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "f-string: expecting '}'",
#  'unterminated string literal',
#  "'{' was never closed",
#  "unmatched ')'",
#  'too many statically nested blocks',
#  'f-string: empty expression not allowed',
#  "annotated name '_sex_animations_playlists' can't be global",
#  "expected 'except' or 'finally' block",
#  'too many nested parentheses',
#  "'break' outside loop",
#  'illegal target for annotation',
#  'too many nested parentheses',
#  'invalid syntax. perhaps you forgot a comma?',
#  'unexpected indent',
#  "f-string: single '}' is not allowed",
#  "expected '('",
#  'f-string: invalid syntax',
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  'unterminated string literal',
#  "':' expected after dictionary key",
#  "f-string: expecting a valid expression after '{'",
#  "f-string: single '}' is not allowed",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'positional argument follows keyword argument',
#  'unexpected eof while parsing',
#  'trailing comma not allowed without surrounding parentheses',
#  "expected 'except' or 'finally' block",
#  'eol while scanning string literal',
#  "f-string: single '}' is not allowed",
#  'unexpected indent',
#  "'(' was never closed",
#  "f-string: f-string: unmatched ')'",
#  "'await' outside function",
#  'f-string: empty expression not allowed',
#  "annotated name 'undressable_parts' can't be global",
#  "f-string: single '}' is not allowed",
#  "f-string: single '}' is not allowed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'{' was never closed",
#  "'(' was never closed",
#  "'continue' not properly in loop",
#  "'[' was never closed",
#  'unterminated string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unexpected character after line continuation character',
#  'unexpected indent',
#  'unexpected indent',
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 14",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'[' was never closed",
#  "'continue' not properly in loop",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "unmatched ')'",
#  "expected 'except' or 'finally' block",
#  "invalid character '🔱'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "f-string: expecting '!', or ':', or '}'",
#  'unterminated string literal',
#  'invalid syntax. perhaps you forgot a comma?',
#  "'{' was never closed",
#  'unterminated string literal',
#  "'break' outside loop",
#  "f-string: unmatched '['",
#  "'{' was never closed",
#  'unexpected indent',
#  "unmatched ')'",
#  "expected 'except' or 'finally' block",
#  "f-string: single '}' is not allowed",
#  "'{' was never closed",
#  "'[' was never closed",
#  "':' expected after dictionary key",
#  "expected 'except' or 'finally' block",
#  'unindent does not match any outer indentation level',
#  'unterminated string literal ; perhaps you escaped the end quote?',
#  "'{' was never closed",
#  'invalid non-printable character u+105244',
#  'non-default argument follows default argument',
#  'invalid syntax. perhaps you forgot a comma?',
#  'invalid decimal literal',
#  "expected 'except' or 'finally' block",
#  "':' expected after dictionary key",
#  "f-string: single '}' is not allowed",
#  'unterminated string literal',
#  "expected 'else' after 'if' expression",
#  "'[' was never closed",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  'f-string: empty expression not allowed',
#  "'(' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 10",
#  "'(' was never closed",
#  "':' expected after dictionary key",
#  "unmatched '}'",
#  "cannot assign to literal here. maybe you meant '==' instead of '='?",
#  "expected 'except' or 'finally' block",
#  'too many nested parentheses',
#  'unterminated string literal',
#  'unterminated string literal',
#  "f-string: unmatched '('",
#  "'(' was never closed",
#  'eol while scanning string literal',
#  "invalid character '²'",
#  "'[' was never closed",
#  'unexpected unindent',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "annotated name '_relationship_settings_capture' can't be global",
#  'f-string: invalid syntax',
#  "'continue' not properly in loop",
#  'unterminated string literal',
#  "expected 'else' after 'if' expression",
#  "invalid character '█'",
#  "expected 'except' or 'finally' block",
#  "no binding for nonlocal 'i' found",
#  "'{' was never closed",
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  "'{' was never closed",
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "':' expected after dictionary key",
#  "invalid character 'ِ'",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "unmatched ')'",
#  "'{' was never closed",
#  "f-string: single '}' is not allowed",
#  "'break' outside loop",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unexpected indent',
#  "'continue' not properly in loop",
#  "unmatched ']'",
#  "f-string: single '}' is not allowed",
#  'unterminated triple-quoted string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 56",
#  "'(' was never closed",
#  "f-string: single '}' is not allowed",
#  'unexpected indent',
#  'f-string expression part cannot include a backslash',
#  "f-string: expecting '}'",
#  "expected 'except' or 'finally' block",
#  "f-string: single '}' is not allowed",
#  "invalid character '🌀'",
#  "f-string: unmatched '['",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "annotated name '_relationship_settings_capture' can't be global",
#  "annotated name 'settings_keys' can't be global",
#  "expected 'else' after 'if' expression",
#  'invalid syntax. perhaps you forgot a comma?',
#  'expected an indented block after function definition on line 46',
#  'invalid \\x escape at position 1390',
#  'invalid decimal literal',
#  "'(' was never closed",
#  "'continue' not properly in loop",
#  'keyword argument repeated: r',
#  'f-string: empty expression not allowed',
#  'unterminated string literal',
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  'unexpected indent',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unexpected character after line continuation character',
#  "f-string: valid expression required before '}'",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 146",
#  "f-string: valid expression required before '}'",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "expected 'except' or 'finally' block",
#  "f-string: single '}' is not allowed",
#  'cannot assign to expression',
#  'unexpected character after line continuation character',
#  "unmatched ')'",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 28",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "'[' was never closed",
#  'invalid syntax. perhaps you forgot a comma?',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'invalid \\x escape at position 5337',
#  'too many nested parentheses',
#  'unindent does not match any outer indentation level',
#  'unexpected character after line continuation character',
#  'f-string: empty expression not allowed',
#  "'(' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "annotated name '_relationship_settings_capture' can't be global",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 236",
#  "f-string: single '}' is not allowed",
#  'unterminated string literal',
#  "f-string: expecting '}'",
#  'unterminated string literal',
#  'unexpected indent',
#  "expected '('",
#  "'break' outside loop",
#  "f-string: expecting '!', or ':', or '}'",
#  "invalid character '🌀'",
#  'unexpected indent',
#  "'{' was never closed",
#  "unmatched ')'",
#  "'continue' not properly in loop",
#  'f-string expression part cannot include a backslash',
#  "f-string: expecting '=', or '!', or ':', or '}'",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'[' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "':' expected after dictionary key",
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'{' was never closed",
#  "annotated name 'summoned_sims' can't be global",
#  'unterminated string literal',
#  "f-string: single '}' is not allowed",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "'{' was never closed",
#  'unterminated string literal',
#  "unmatched ')'",
#  'keyword argument repeated',
#  'f-string expression part cannot include a backslash',
#  "f-string: expecting a valid expression after '{'",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "unmatched ')'",
#  "annotated name '_master_settings_capture' can't be global",
#  'unexpected character after line continuation character',
#  "f-string: unmatched '['",
#  'unindent does not match any outer indentation level',
#  'unterminated string literal',
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "'{' was never closed",
#  'invalid syntax. perhaps you forgot a comma?',
#  'invalid decimal literal',
#  "f-string: single '}' is not allowed",
#  'invalid syntax. perhaps you forgot a comma?',
#  'unterminated string literal',
#  "':' expected after dictionary key",
#  "annotated name '_relationship_settings_capture' can't be global",
#  "annotated name '_sex_animations_recently_used' can't be global",
#  "'{' was never closed",
#  "default 'except:' must be last",
#  "expected 'except' or 'finally' block",
#  "'break' outside loop",
#  'unexpected indent',
#  "'{' was never closed",
#  "cannot assign to subscript here. maybe you meant '==' instead of '='?",
#  'invalid syntax. perhaps you forgot a comma?',
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "expression expected after dictionary key and ':'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'too many nested parentheses',
#  "'(' was never closed",
#  "cannot assign to expression here. maybe you meant '==' instead of '='?",
#  'unexpected indent',
#  "duplicate argument 'asesor_de_inversiones' in function definition",
#  'invalid syntax. perhaps you forgot a comma?',
#  'unterminated string literal',
#  "annotated name '_sex_positioning_data' can't be global",
#  'unterminated string literal',
#  'invalid syntax. perhaps you forgot a comma?',
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  'unterminated string literal',
#  'unexpected indent',
#  'unterminated f-string literal',
#  'invalid character in identifier',
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 31",
#  "f-string: single '}' is not allowed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 273",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unterminated string literal',
#  "'(' was never closed",
#  "'[' was never closed",
#  'unexpected indent',
#  "annotated name 'db2' can't be global",
#  'f-string expression part cannot include a backslash',
#  "'{' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 31",
#  "'{' was never closed",
#  'keyword argument repeated: expand',
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 32",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 191",
#  "invalid character '�'",
#  'invalid syntax. perhaps you forgot a comma?',
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "expected ':'",
#  "invalid character '│'",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "':' expected after dictionary key",
#  "':' expected after dictionary key",
#  'keyword argument repeated',
#  "annotated name '_relationship_settings_capture' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unterminated string literal',
#  "f-string: unmatched ')'",
#  "annotated name 'version_control' can't be global",
#  "f-string: valid expression required before '}'",
#  'unterminated string literal',
#  'unindent does not match any outer indentation level',
#  'unterminated f-string literal',
#  'invalid syntax. perhaps you forgot a comma?',
#  "f-string: single '}' is not allowed",
#  "annotated name 'settings' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  "annotated name '_orchestrator_context' can't be global",
#  'too many nested parentheses',
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "f-string: valid expression required before '}'",
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "invalid character '␘'",
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'unterminated string literal',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'invalid syntax. perhaps you forgot a comma?',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  'unterminated string literal',
#  'unexpected character after line continuation character',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'(' was never closed",
#  "'[' was never closed",
#  'f-string expression part cannot include a backslash',
#  "'{' was never closed",
#  'unindent does not match any outer indentation level',
#  "invalid character '🌸'",
#  "expected 'except' or 'finally' block",
#  "f-string: single '}' is not allowed",
#  "default 'except:' must be last",
#  'unexpected indent',
#  "'[' was never closed",
#  'unterminated f-string literal',
#  'unterminated f-string literal',
#  "annotated name '_relationship_settings_capture' can't be global",
#  'unterminated string literal',
#  'unterminated string literal',
#  "f-string: expecting '!', or ':', or '}'",
#  "expected 'except' or 'finally' block",
#  "'(' was never closed",
#  "'{' was never closed",
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 1282",
#  'unexpected indent',
#  "f-string: unmatched '('",
#  "'[' was never closed",
#  'f-string: empty expression not allowed',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 1282",
#  "'{' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 38",
#  'keyword argument repeated: operation_name',
#  "f-string: single '}' is not allowed",
#  "f-string: valid expression required before '}'",
#  "unmatched ']'",
#  "'{' was never closed",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'[' was never closed",
#  'too many levels of indentation',
#  'unterminated string literal',
#  'unindent does not match any outer indentation level',
#  "f-string: single '}' is not allowed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'too many nested parentheses',
#  "f-string: valid expression required before '}'",
#  "invalid character '【'",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  "'async for' outside async function",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'unexpected indent',
#  "'break' outside loop",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "duplicate argument 'pydev_file' in function definition",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'unexpected indent',
#  "unmatched '}'",
#  'unexpected character after line continuation character',
#  'unterminated string literal',
#  "f-string: valid expression required before '}'",
#  'invalid syntax. perhaps you forgot a comma?',
#  "'unicodeescape' codec can't decode bytes in position 58-59: truncated \\uxxxx escape",
#  'too many levels of indentation',
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  'unexpected indent',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "default 'except:' must be last",
#  "'[' was never closed",
#  "no binding for nonlocal 'app_exc' found",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 109",
#  'unterminated string literal',
#  "invalid character '🌀'",
#  'f-string: invalid syntax',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unterminated string literal',
#  'too many nested parentheses',
#  'invalid non-printable character u+200d',
#  'too many nested parentheses',
#  "annotated name '_favorite_animations_identifiers' can't be global",
#  "expected 'else' after 'if' expression",
#  "f-string: expecting '=', or '!', or ':', or '}'",
#  "'{' was never closed",
#  'f-string: invalid syntax',
#  'unexpected indent',
#  'unexpected indent',
#  "':' expected after dictionary key",
#  "expected ':'",
#  'f-string: invalid syntax',
#  'f-string: empty expression not allowed',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "f-string: unmatched '['",
#  "'[' was never closed",
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 670",
#  "f-string: single '}' is not allowed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'f-string: empty expression not allowed',
#  "':' expected after dictionary key",
#  "unmatched ')'",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'unexpected indent',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'unexpected indent',
#  'unterminated string literal',
#  'unexpected character after line continuation character',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 79",
#  "expected 'except' or 'finally' block",
#  "expected 'except' or 'finally' block",
#  "annotated name 'btn_y' can't be global",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "'{' was never closed",
#  "'(' was never closed",
#  "expected 'else' after 'if' expression",
#  'did you forget parentheses around the comprehension target?',
#  'invalid hexadecimal literal',
#  "'(' was never closed",
#  'too many nested parentheses',
#  "'[' was never closed",
#  "annotated name 'version_control' can't be global",
#  "'(' was never closed",
#  "annotated name '_sex_animations_use_count' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 52",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'cannot assign to conditional expression',
#  'unexpected indent',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'cannot assign to literal',
#  "'{' was never closed",
#  "annotated name 'marriage_rename_list' can't be global",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 167",
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  'unterminated string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'break' outside loop",
#  "f-string: expecting a valid expression after '{'",
#  "expected 'except' or 'finally' block",
#  'f-string: empty expression not allowed',
#  'cannot assign to function call',
#  "expected 'else' after 'if' expression",
#  "invalid character '！'",
#  'invalid decimal literal',
#  "expected 'except' or 'finally' block",
#  'invalid decimal literal',
#  "'(' was never closed",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "f-string: unmatched '['",
#  'unexpected indent',
#  'unterminated f-string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'too many nested parentheses',
#  'keyword argument repeated: description',
#  'unterminated string literal',
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "expected 'except' or 'finally' block",
#  "'[' was never closed",
#  'too many nested parentheses',
#  "'{' was never closed",
#  "':' expected after dictionary key",
#  'too many levels of indentation',
#  'invalid syntax. perhaps you forgot a comma?',
#  "f-string: expecting a valid expression after '{'",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 345",
#  "'{' was never closed",
#  "f-string: single '}' is not allowed",
#  "unmatched ']'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "expected 'else' after 'if' expression",
#  "cannot assign to subscript here. maybe you meant '==' instead of '='?",
#  'did you forget parentheses around the comprehension target?',
#  'unterminated string literal',
#  'expected an indented block after function definition on line 9',
#  'keyword argument repeated: platforms',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "annotated name 'marriage_rename_list' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'{' was never closed",
#  'f-string: invalid syntax',
#  'too many nested parentheses',
#  "'{' was never closed",
#  "cannot assign to literal here. maybe you meant '==' instead of '='?",
#  'unterminated string literal',
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "expected 'except' or 'finally' block",
#  "'[' was never closed",
#  "expected 'except' or 'finally' block",
#  "annotated name '_sex_positioning_data' can't be global",
#  "'break' outside loop",
#  "default 'except:' must be last",
#  'unterminated string literal',
#  "expected 'except' or 'finally' block",
#  "'{' was never closed",
#  "f-string: single '}' is not allowed",
#  "'break' outside loop",
#  'unindent does not match any outer indentation level',
#  "f-string: expecting a valid expression after '{'",
#  "'[' was never closed",
#  'invalid syntax. perhaps you forgot a comma?',
#  "'{' was never closed",
#  "unmatched ']'",
#  "'continue' not properly in loop",
#  "'[' was never closed",
#  "f-string: expecting '!', or ':', or '}'",
#  "f-string: expecting '!', or ':', or '}'",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 182",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "f-string: valid expression required before '}'",
#  "invalid character '║'",
#  "annotated name '_master_settings_capture' can't be global",
#  "invalid character '❌'",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'f-string: empty expression not allowed',
#  "default 'except:' must be last",
#  "'break' outside loop",
#  "'{' was never closed",
#  'unindent does not match any outer indentation level',
#  "f-string: single '}' is not allowed",
#  "'break' outside loop",
#  'did you forget parentheses around the comprehension target?',
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  "'{' was never closed",
#  "expected 'except' or 'finally' block",
#  'f-string expression part cannot include a backslash',
#  "expected ':'",
#  "':' expected after dictionary key",
#  'keyword argument repeated: step_sequence',
#  'keyword argument repeated',
#  "expected 'except' or 'finally' block",
#  "'(' was never closed",
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  'unexpected indent',
#  "invalid character '：'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'unterminated string literal',
#  'unexpected character after line continuation character',
#  'unterminated string literal',
#  "f-string: expecting a valid expression after '{'",
#  'unterminated string literal',
#  'unterminated string literal',
#  "'(' was never closed",
#  "'{' was never closed",
#  "expected 'except' or 'finally' block",
#  'unexpected character after line continuation character',
#  "expected 'else' after 'if' expression",
#  "'[' was never closed",
#  'cannot delete none',
#  "f-string: expecting '=', or '!', or ':', or '}'",
#  'invalid syntax. perhaps you forgot a comma?',
#  "'[' was never closed",
#  'cannot assign to expression',
#  'f-string: invalid syntax',
#  'invalid syntax. perhaps you forgot a comma?',
#  "f-string: single '}' is not allowed",
#  "'[' was never closed",
#  'trailing comma not allowed without surrounding parentheses',
#  "'(' was never closed",
#  'positional argument follows keyword argument unpacking',
#  'unterminated string literal',
#  'f-string: expressions nested too deeply',
#  'unterminated string literal',
#  'eol while scanning string literal',
#  'unterminated string literal',
#  "'{' was never closed",
#  "'(' was never closed",
#  'cannot assign to expression',
#  'unindent does not match any outer indentation level',
#  "annotated name '_relationship_settings_capture' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 39",
#  'unexpected indent',
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "'(' was never closed",
#  "f-string: single '}' is not allowed",
#  "'[' was never closed",
#  'unexpected indent',
#  "f-string: single '}' is not allowed",
#  "f-string: expecting '}'",
#  "expected 'except' or 'finally' block",
#  'f-string expression part cannot include a backslash',
#  "f-string: valid expression required before '}'",
#  "default 'except:' must be last",
#  'cannot assign to literal',
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  'unindent does not match any outer indentation level',
#  'unexpected unindent',
#  "f-string: single '}' is not allowed",
#  "expected 'except' or 'finally' block",
#  'cannot assign to expression',
#  'unterminated string literal',
#  "annotated name '_menstrual_absolute_time_override' can't be global",
#  'unexpected indent',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "closing parenthesis '}' does not match opening parenthesis '(' on line 155",
#  "'continue' not properly in loop",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  'unterminated string literal',
#  'invalid syntax. perhaps you forgot a comma?',
#  'invalid syntax. perhaps you forgot a comma?',
#  "'break' outside loop",
#  "f-string: single '}' is not allowed",
#  "name 'diskfullloggedcount' is assigned to before global declaration",
#  "unmatched ')'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'unterminated string literal',
#  "expected 'else' after 'if' expression",
#  'invalid syntax. perhaps you forgot a comma?',
#  'too many nested parentheses',
#  'unindent does not match any outer indentation level',
#  "':' expected after dictionary key",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "annotated name '_sex_settings_capture' can't be global",
#  'unterminated triple-quoted string literal',
#  "annotated name '_sex_animations_playlists' can't be global",
#  "annotated name '_menstrual_absolute_time_override' can't be global",
#  "unmatched ')'",
#  "f-string: expecting a valid expression after '{'",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 129",
#  "expected 'except' or 'finally' block",
#  "'(' was never closed",
#  'f-string: empty expression not allowed',
#  'eol while scanning string literal',
#  'invalid decimal literal',
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 185",
#  'keyword argument repeated: output_text',
#  'unexpected indent',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 83",
#  'unterminated string literal',
#  'unexpected indent',
#  'f-string: invalid syntax',
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'parameter without a default follows parameter with a default',
#  'too many levels of indentation',
#  'unexpected character after line continuation character',
#  'invalid syntax. perhaps you forgot a comma?',
#  "'[' was never closed",
#  "expected ':'",
#  "unmatched ')'",
#  "expected 'except' or 'finally' block",
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'{' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 28",
#  'f-string: invalid syntax',
#  "'[' was never closed",
#  "'{' was never closed",
#  "'return' outside function",
#  'f-string: invalid syntax',
#  "invalid character '₀'",
#  'invalid syntax. perhaps you forgot a comma?',
#  "duplicate argument 'wxxxxxxxxxxxxxxwwxxxxxwwwxwwxwwxwwwwxxwxxwxwwwxwwxwwxxxwxwxxxwwwwwxxwxwwwwxwxxxwxxxwwxwxxwwxwxwwxwwwwxxxwxxwwwxxwxxxwxxwxxwwwxwxwxxwwxxwwxwwwwxwxxwwxxxwxwwxxwwwwwwwwwxxxwxxwwwxxxwwxxwxxwwwwxxwwwxwwxxwxxxxxxwwxww' in function definition",
#  "annotated name '_relationship_settings_capture' can't be global",
#  'invalid syntax. perhaps you forgot a comma?',
#  'keyword argument repeated',
#  'unexpected indent',
#  "annotated name 'count' can't be global",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'unterminated string literal',
#  'unexpected indent',
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 496",
#  "expected 'else' after 'if' expression",
#  'non-default argument follows default argument',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'unexpected indent',
#  'unexpected indent',
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 6",
#  "f-string: expecting a valid expression after '{'",
#  "'{' was never closed",
#  'unterminated string literal',
#  'unterminated triple-quoted string literal',
#  "f-string: expecting '}'",
#  "'[' was never closed",
#  "default 'except:' must be last",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "':' expected after dictionary key",
#  'import * only allowed at module level',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "expected 'else' after 'if' expression",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "invalid character '。'",
#  "f-string: expecting a valid expression after '{'",
#  'invalid syntax. perhaps you forgot a comma?',
#  "f-string: expecting '!', or ':', or '}'",
#  'f-string expression part cannot include a backslash',
#  "f-string: expecting a valid expression after '{'",
#  'invalid non-printable character u+200c',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 28",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  'keyword argument repeated: install_requires',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'f-string: unterminated string',
#  "f-string: valid expression required before '}'",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'unexpected indent',
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "f-string: single '}' is not allowed",
#  "expected 'except' or 'finally' block",
#  'positional argument follows keyword argument',
#  'unterminated string literal',
#  'positional argument follows keyword argument',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 33",
#  'f-string: invalid syntax',
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 25",
#  "expected ':'",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "'[' was never closed",
#  "'await' outside function",
#  'f-string: empty expression not allowed',
#  'unexpected indent',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "f-string: unmatched '('",
#  "unmatched ')'",
#  "expected 'else' after 'if' expression",
#  "f-string: single '}' is not allowed",
#  'invalid decimal literal',
#  "'{' was never closed",
#  "annotated name 'version_control' can't be global",
#  'too many levels of indentation',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unterminated triple-quoted string literal',
#  "cannot assign to subscript here. maybe you meant '==' instead of '='?",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'unindent does not match any outer indentation level',
#  "invalid character '🚨'",
#  'unindent does not match any outer indentation level',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "f-string: unmatched '('",
#  "expected an indented block after 'match' statement on line 425",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'f-string expression part cannot include a backslash',
#  'unterminated string literal',
#  'unterminated string literal',
#  "no binding for nonlocal 'chunk_response' found",
#  "f-string: single '}' is not allowed",
#  "invalid character '✖'",
#  'f-string: invalid syntax',
#  "name 'license_valid' is assigned to before global declaration",
#  'did you forget parentheses around the comprehension target?',
#  "'{' was never closed",
#  "cannot assign to function call here. maybe you meant '==' instead of '='?",
#  "f-string: valid expression required before '}'",
#  'invalid syntax. perhaps you forgot a comma?',
#  'positional argument follows keyword argument',
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  'named arguments must follow bare *',
#  "annotated name '_relationship_settings_capture' can't be global",
#  "expected 'except' or 'finally' block",
#  "unmatched ')'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'from __future__ imports must occur at the beginning of the file',
#  "f-string: single '}' is not allowed",
#  "'(' was never closed",
#  'unexpected indent']

# %%
failed_cases_df["precessed_error_message"].to_list()
# Out:
# ["unmatched ')'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'invalid whitespace in between expression, mathematical operands missing',
#  'too many nested parentheses',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'code object added inside tuple',
#  'unterminated string literal',
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  "'(' was never closed",
#  "invalid character '✗'",
#  "expected 'except' or 'finally' block",
#  'unexpected indent',
#  'f-string expression part cannot include a backslash',
#  "missing closing ']' and ')'",
#  'f-string: invalid syntax',
#  'except without try block',
#  'too many nested parentheses',
#  'incomplete in-line ternary operator, bitwise operation on byte object',
#  'invalid whitespace in between expression, mathematical operands missing',
#  'cannot assign to literal',
#  'unterminated string literal',
#  "f-string: single '}' is not allowed",
#  'two key-value pars inside the dictionary comprehension instead of one',
#  "f-string: expecting a valid expression after '{'",
#  "f-string: expecting '!', or ':', or '}'",
#  "no closing '}'",
#  "no closing '}'",
#  'unterminated string literal',
#  "f-string: expecting '}'",
#  "no closing ')', '}', or ']', incomplete expression",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 37",
#  'two for loops in one line',
#  "'[' was never closed",
#  "f-string: expecting a valid expression after '{'",
#  "cannot assign to function call here. maybe you meant '==' instead of '='?",
#  'too many nested parentheses',
#  "f-string: expecting '!', or ':', or '}'",
#  "'{' was never closed",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "'yield' outside function",
#  'unterminated string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'break' outside loop",
#  "no closing '}', incomplete translation, use of raw code object",
#  'except without try block',
#  'else without if block',
#  "no closing '}', invalid indentation for pass",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "'[' was never closed",
#  'unterminated string literal',
#  'else without if block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "annotated name 'version_control' can't be global",
#  'else without if block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "cannot assign to literal here. maybe you meant '==' instead of '='?",
#  'keyword argument repeated',
#  'invalid syntax. perhaps you forgot a comma?',
#  'else without if block',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "f-string: expecting '}'",
#  'else without if block',
#  'unterminated string literal',
#  "'{' was never closed",
#  "unmatched ')'",
#  'too many statically nested blocks',
#  'f-string: empty expression not allowed',
#  "annotated name '_sex_animations_playlists' can't be global",
#  'incomplete translation, code object usage in program',
#  "expected 'except' or 'finally' block",
#  'too many nested parentheses',
#  "'break' outside loop",
#  'illegal target for annotation',
#  'too many nested parentheses',
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'unexpected indent',
#  "f-string: single '}' is not allowed",
#  "expected '('",
#  "curly braces ({ }) in PowerShell command conflicting with Python's f-string formatting using uses { } to insert variables",
#  "no closing ']' on previous line",
#  'unterminated string literal',
#  "':' expected after dictionary key",
#  "f-string: expecting a valid expression after '{'",
#  "f-string: single '}' is not allowed",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'if condition using = instead of == as well as a comma (,)',
#  'positional argument follows keyword argument',
#  'unexpected eof while parsing',
#  'trailing comma not allowed without surrounding parentheses',
#  "expected 'except' or 'finally' block",
#  'else without if block',
#  'eol while scanning string literal',
#  "f-string: single '}' is not allowed",
#  'unexpected indent',
#  "'(' was never closed",
#  "f-string: f-string: unmatched ')'",
#  "'await' outside function",
#  'f-string: empty expression not allowed',
#  "no closing '[', invalid use of numpy.nan, using it as subscriptable when it is not",
#  "annotated name 'undressable_parts' can't be global",
#  "f-string: single '}' is not allowed",
#  "f-string: single '}' is not allowed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'{' was never closed",
#  "'(' was never closed",
#  "'continue' not properly in loop",
#  "'[' was never closed",
#  'unterminated string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "missing closing parenthesis ')' and an incorrect number of closing brackets ']'",
#  'unexpected character after line continuation character',
#  'unexpected indent',
#  'unexpected indent',
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 14",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'[' was never closed",
#  "'continue' not properly in loop",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'except without try block',
#  "unmatched ')'",
#  'else without if block',
#  "expected 'except' or 'finally' block",
#  'no function or class after decorator',
#  "invalid character '🔱'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "f-string: expecting '!', or ':', or '}'",
#  'unterminated string literal',
#  'invalid syntax. perhaps you forgot a comma?',
#  "'{' was never closed",
#  'unterminated string literal',
#  "'break' outside loop",
#  "f-string: unmatched '['",
#  "'{' was never closed",
#  'else without if block',
#  "no closing '}', incomplete translation",
#  'unexpected indent',
#  'regular expression  missing its quotes',
#  "unmatched ')'",
#  "expected 'except' or 'finally' block",
#  "f-string: single '}' is not allowed",
#  'missing a closing bracket ], parenthesis ), or brace }',
#  'tryung to add lambda function to a value, invalid use of lambda function',
#  "'{' was never closed",
#  'except without try block',
#  "'[' was never closed",
#  "':' expected after dictionary key",
#  "expected 'except' or 'finally' block",
#  'unindent does not match any outer indentation level',
#  'unterminated string literal ; perhaps you escaped the end quote?',
#  "'{' was never closed",
#  'invalid non-printable character u+105244',
#  'non-default argument follows default argument',
#  'invalid syntax. perhaps you forgot a comma?',
#  'invalid decimal literal',
#  "expected 'except' or 'finally' block",
#  'else without if block',
#  "':' expected after dictionary key",
#  "f-string: single '}' is not allowed",
#  "incomplete translation, use of <mask_*> as variable, missing closing or matching braces '}'",
#  'unterminated string literal',
#  "expected 'else' after 'if' expression",
#  'else without if block',
#  "'[' was never closed",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  'f-string: empty expression not allowed',
#  "'(' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 10",
#  "'(' was never closed",
#  "':' expected after dictionary key",
#  "unmatched '}'",
#  "cannot assign to literal here. maybe you meant '==' instead of '='?",
#  "expected 'except' or 'finally' block",
#  'no function or class after decorator',
#  'too many nested parentheses',
#  'unterminated string literal',
#  'unterminated string literal',
#  "f-string: unmatched '('",
#  "'(' was never closed",
#  'eol while scanning string literal',
#  "invalid character '²'",
#  "'[' was never closed",
#  'unexpected unindent',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "annotated name '_relationship_settings_capture' can't be global",
#  'except without try block',
#  'f-string: invalid syntax',
#  'invalid variable name, invalid key in dictionary, no closing brace',
#  "'continue' not properly in loop",
#  'unterminated string literal',
#  "expected 'else' after 'if' expression",
#  "invalid character '█'",
#  'match without case block',
#  "expected 'except' or 'finally' block",
#  "no binding for nonlocal 'i' found",
#  'else without if block',
#  "'{' was never closed",
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  "'{' was never closed",
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "invalid indent, no matching closing '}' or ']'",
#  "':' expected after dictionary key",
#  "invalid character 'ِ'",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "unmatched ')'",
#  "no closing ']' on previous line, incomplete translation",
#  "'{' was never closed",
#  'missing tripple quote on docstring',
#  "f-string: single '}' is not allowed",
#  "'break' outside loop",
#  'invalid indent, finally outside try catch block level',
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unexpected indent',
#  "'continue' not properly in loop",
#  "unmatched ']'",
#  "f-string: single '}' is not allowed",
#  'unterminated triple-quoted string literal',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'except without try block',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 56",
#  'else without if block',
#  "'(' was never closed",
#  "f-string: single '}' is not allowed",
#  'match without case block',
#  'unexpected indent',
#  'f-string expression part cannot include a backslash',
#  "f-string: expecting '}'",
#  'missing class or function definition after decorator',
#  "expected 'except' or 'finally' block",
#  'invalid syntax',
#  "f-string: single '}' is not allowed",
#  "invalid character '🌀'",
#  "incomplete translation, missing closing brace '}'",
#  'else without if block',
#  "f-string: unmatched '['",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'incorrect use of the if and else statements in a list comprehension',
#  "annotated name '_relationship_settings_capture' can't be global",
#  "annotated name 'settings_keys' can't be global",
#  "expected 'else' after 'if' expression",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'expected an indented block after function definition on line 46',
#  'invalid \\x escape at position 1390',
#  'invalid decimal literal',
#  "'(' was never closed",
#  "'continue' not properly in loop",
#  'keyword argument repeated: r',
#  'f-string: empty expression not allowed',
#  'unterminated string literal',
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  'unexpected indent',
#  'else without if block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unexpected character after line continuation character',
#  "f-string: valid expression required before '}'",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 146",
#  "f-string: valid expression required before '}'",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "expected 'except' or 'finally' block",
#  "f-string: single '}' is not allowed",
#  'cannot assign to expression',
#  'unexpected character after line continuation character',
#  "unmatched closing ']'s, incomplete translation",
#  'else without if block',
#  "unmatched ')'",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 28",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "'[' was never closed",
#  'invalid syntax. perhaps you forgot a comma?',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'invalid \\x escape at position 5337',
#  'too many nested parentheses',
#  'unindent does not match any outer indentation level',
#  'except without try block',
#  'unexpected character after line continuation character',
#  'f-string: empty expression not allowed',
#  "'(' was never closed",
#  'no class or function defined after decorator',
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "annotated name '_relationship_settings_capture' can't be global",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 236",
#  "f-string: single '}' is not allowed",
#  'unterminated string literal',
#  'finally outside of try except block level',
#  'excessive nesting of lambda function, incomplete translation, unmatched or missing parentheses',
#  'else without if block',
#  "f-string: expecting '}'",
#  'except without try block',
#  'unterminated string literal',
#  'unexpected indent',
#  'else without if block',
#  "expected '('",
#  "'break' outside loop",
#  'multiple for loops in one line without separation',
#  "f-string: expecting '!', or ':', or '}'",
#  "invalid character '🌀'",
#  'unexpected indent',
#  'except without try block',
#  "'{' was never closed",
#  "unmatched ')'",
#  "'continue' not properly in loop",
#  'else without if block',
#  'f-string expression part cannot include a backslash',
#  'except without try block',
#  'no function or class after decorator',
#  "f-string: expecting '=', or '!', or ':', or '}'",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'[' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  'no function or class after decorator',
#  "':' expected after dictionary key",
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'{' was never closed",
#  "annotated name 'summoned_sims' can't be global",
#  'unterminated string literal',
#  "f-string: single '}' is not allowed",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "'{' was never closed",
#  'else without if block',
#  'no function or class after decorator',
#  'unterminated string literal',
#  "unmatched ')'",
#  'keyword argument repeated',
#  'f-string expression part cannot include a backslash',
#  "f-string: expecting a valid expression after '{'",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "unmatched ')'",
#  "annotated name '_master_settings_capture' can't be global",
#  'unexpected character after line continuation character',
#  'no function or class after decorator',
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "f-string: unmatched '['",
#  'unindent does not match any outer indentation level',
#  'unterminated string literal',
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  'except without try block',
#  "'{' was never closed",
#  'no function or class after decorator',
#  'no function or class after decorator, mismatched indentation, except outside or without try block',
#  'invalid syntax. perhaps you forgot a comma?',
#  'invalid decimal literal',
#  "missing brace '}', incomplete translation",
#  "f-string: single '}' is not allowed",
#  'invalid syntax. perhaps you forgot a comma?',
#  'unterminated string literal',
#  'mismatched closing parantheses, incomplete translation',
#  'no class or function defined after decorator',
#  'incompatible use of tuple leading to invalid expression, no separation between loops',
#  "':' expected after dictionary key",
#  'incomplete translation, missing or unmatched closing parantheses',
#  "annotated name '_relationship_settings_capture' can't be global",
#  'no class or function defined after decorator',
#  "annotated name '_sex_animations_recently_used' can't be global",
#  "'{' was never closed",
#  "default 'except:' must be last",
#  "expected 'except' or 'finally' block",
#  "'break' outside loop",
#  'unexpected indent',
#  'passing string as parameter name',
#  "'{' was never closed",
#  "cannot assign to subscript here. maybe you meant '==' instead of '='?",
#  'invalid syntax. perhaps you forgot a comma?',
#  'else without if block',
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "expression expected after dictionary key and ':'",
#  'else without if block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'no class or function defined after decorator',
#  'too many nested parentheses',
#  "'(' was never closed",
#  "cannot assign to expression here. maybe you meant '==' instead of '='?",
#  'unexpected indent',
#  "duplicate argument 'asesor_de_inversiones' in function definition",
#  "missing closing bracket ']', incomplete translation",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'unterminated string literal',
#  "annotated name '_sex_positioning_data' can't be global",
#  'unterminated string literal',
#  'invalid syntax. perhaps you forgot a comma?',
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'unterminated string literal',
#  'unexpected indent',
#  'no closing parenthesis',
#  'unterminated f-string literal',
#  'invalid character in identifier',
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 31",
#  "f-string: single '}' is not allowed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'key is missing value, repeated same key as well',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 273",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'else without if block',
#  'except without try block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unterminated string literal',
#  'no class or function defined after decorator',
#  "'(' was never closed",
#  "'[' was never closed",
#  'mismatched closing paranthesis and brackets, incomplete translation',
#  'unexpected indent',
#  "annotated name 'db2' can't be global",
#  'f-string expression part cannot include a backslash',
#  "'{' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 31",
#  "'{' was never closed",
#  'keyword argument repeated: expand',
#  'except without try block',
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 32",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 191",
#  "invalid character '�'",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "missing brackets ']', mismatched closing brackets, parenthesis, braces and incomplete translation",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'variables are declared with whitespace in names',
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "incomplete if, no ':'",
#  'except without try block',
#  'incorrect use of if-else inside list comprehension',
#  "expected ':'",
#  "invalid character '│'",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "':' expected after dictionary key",
#  "':' expected after dictionary key",
#  'inclomplete translation, code object usage as a variable',
#  'keyword argument repeated',
#  "annotated name '_relationship_settings_capture' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unterminated string literal',
#  "f-string: unmatched ')'",
#  'match without case structure',
#  "no closing bracket ']'",
#  'incomplete translation, use of internal markers (<mask>), code object usage as a variable or attribute',
#  "annotated name 'version_control' can't be global",
#  "f-string: valid expression required before '}'",
#  'unterminated string literal',
#  'missing count of closing brackets and braces, incomplete translation',
#  'unindent does not match any outer indentation level',
#  'except without try block',
#  'no class or function defined after decorator',
#  'except without try block',
#  'else without if block',
#  'unterminated f-string literal',
#  'invalid syntax. perhaps you forgot a comma?',
#  "f-string: single '}' is not allowed",
#  "annotated name 'settings' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  'else without if block',
#  "annotated name '_orchestrator_context' can't be global",
#  'too many nested parentheses',
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  'else without if block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "f-string: valid expression required before '}'",
#  'no class or function defined after decorator',
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "invalid character '␘'",
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'unterminated string literal',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'invalid syntax. perhaps you forgot a comma?',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  'unterminated string literal',
#  'unexpected character after line continuation character',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'(' was never closed",
#  "'[' was never closed",
#  'else without if block',
#  'attempting to join the string with a list comprehension that is not a string',
#  'f-string expression part cannot include a backslash',
#  'else without if block',
#  "'{' was never closed",
#  'inaccurate use of self in defining a function',
#  'else without if block',
#  'unindent does not match any outer indentation level',
#  "invalid character '🌸'",
#  "expected 'except' or 'finally' block",
#  'else without if block',
#  "f-string: single '}' is not allowed",
#  "default 'except:' must be last",
#  'unexpected indent',
#  "'[' was never closed",
#  'unterminated f-string literal',
#  'unterminated f-string literal',
#  'invalud variable name, incomplete statement, mismatch in closing brackets',
#  'usage of type hint as argument name',
#  "annotated name '_relationship_settings_capture' can't be global",
#  'unterminated string literal',
#  'unterminated string literal',
#  "f-string: expecting '!', or ':', or '}'",
#  "expected 'except' or 'finally' block",
#  'missing import, incomplete "from" statement',
#  'missing braces, incomplete translation',
#  "'(' was never closed",
#  "missing closing bracket ']', braces '}'; incomplete translation",
#  "'{' was never closed",
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 1282",
#  "no closing bracket ']', parenthesis ')', or brace '}'",
#  'else without if block',
#  'unexpected indent',
#  "f-string: unmatched '('",
#  "'[' was never closed",
#  'f-string: empty expression not allowed',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 1282",
#  "'{' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 38",
#  'keyword argument repeated: operation_name',
#  'incomplete statement, statement terminated before ending properly',
#  "f-string: single '}' is not allowed",
#  "f-string: valid expression required before '}'",
#  "unmatched ']'",
#  "'{' was never closed",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'code object usage inside for loop',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'[' was never closed",
#  'except without try block',
#  'too many levels of indentation',
#  'key-value pair is outside the main dictionary definition.',
#  'unterminated string literal',
#  'unindent does not match any outer indentation level',
#  "f-string: single '}' is not allowed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'too many nested parentheses',
#  "f-string: valid expression required before '}'",
#  'last key-value pair is incomplete',
#  "invalid character '【'",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "closing parenthesis ')' does not match opening parenthesis '['",
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  "'async for' outside async function",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'unexpected indent',
#  "'break' outside loop",
#  "missing bracket ']', list never closed",
#  'use of code object in python file resulting in in valid syntax',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "duplicate argument 'pydev_file' in function definition",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'missing braces, incomplete translation',
#  'unexpected indent',
#  'no class or function defined after decorator',
#  "unmatched '}'",
#  'unexpected character after line continuation character',
#  'unterminated string literal',
#  'hain commands with commas on the except line.',
#  "f-string: valid expression required before '}'",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'incorrect usage for variable type hint',
#  "'unicodeescape' codec can't decode bytes in position 58-59: truncated \\uxxxx escape",
#  'too many levels of indentation',
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  'unexpected indent',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'no class or function defined after decorator',
#  'match without case structure, no function or class definition after decorator',
#  "default 'except:' must be last",
#  "'[' was never closed",
#  "no binding for nonlocal 'app_exc' found",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 109",
#  "no closing brace '}', invalid indent before pass",
#  'else without if block',
#  'unterminated string literal',
#  "invalid character '🌀'",
#  'f-string: invalid syntax',
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'unterminated string literal',
#  'too many nested parentheses',
#  'invalid non-printable character u+200d',
#  'incomplete translation from internal representation, usage of <mask> as variable',
#  'too many nested parentheses',
#  "annotated name '_favorite_animations_identifiers' can't be global",
#  "expected 'else' after 'if' expression",
#  "f-string: expecting '=', or '!', or ':', or '}'",
#  "'{' was never closed",
#  'f-string: invalid syntax',
#  'unexpected indent',
#  'unexpected indent',
#  "':' expected after dictionary key",
#  "expected ':'",
#  'f-string: invalid syntax',
#  'invalid syntax',
#  'f-string: empty expression not allowed',
#  'finally outside level of try-except block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "f-string: unmatched '['",
#  "'[' was never closed",
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 670",
#  "f-string: single '}' is not allowed",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'f-string: empty expression not allowed',
#  "':' expected after dictionary key",
#  "unmatched ')'",
#  'match without case structure',
#  'finally outside level of try-except block',
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'unexpected indent',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'unexpected indent',
#  '::(-1) is passed as function argument, multiple statements in one line without being spearated only invalid whitespace between them',
#  "no closing bracket ']', parenthesis ')', or brace '}', incomplete translation",
#  'unterminated string literal',
#  'unexpected character after line continuation character',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 79",
#  'match without case structure',
#  "expected 'except' or 'finally' block",
#  "expected 'except' or 'finally' block",
#  "annotated name 'btn_y' can't be global",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'using assignment operator (=) inside reurn statement',
#  "'{' was never closed",
#  "the single curly braces ({ and }) in the string conflicting with Python's f-string formatting",
#  "'(' was never closed",
#  "expected 'else' after 'if' expression",
#  'did you forget parentheses around the comprehension target?',
#  'invalid hexadecimal literal',
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'else without if block',
#  "'(' was never closed",
#  'else without if block',
#  'too many nested parentheses',
#  'else without if block',
#  'else without if block',
#  "'[' was never closed",
#  "annotated name 'version_control' can't be global",
#  "'(' was never closed",
#  "annotated name '_sex_animations_use_count' can't be global",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 52",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'cannot assign to conditional expression',
#  'unexpected indent',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'except without try block',
#  "missing closing bracket ']'",
#  'cannot assign to literal',
#  'no class or function defined after decorator',
#  "'{' was never closed",
#  "annotated name 'marriage_rename_list' can't be global",
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 167",
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  'unterminated string literal',
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'else without if block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'break' outside loop",
#  "f-string: expecting a valid expression after '{'",
#  'incomplete translation, use of <mask_*> as variable, did not escape # line got commented midway',
#  "expected 'except' or 'finally' block",
#  'f-string: empty expression not allowed',
#  'cannot assign to function call',
#  "expected 'else' after 'if' expression",
#  'no or missing closing brackets and braces, incomplete translation',
#  'else without if block',
#  "no closing brace '}', incomplete translation",
#  "invalid character '！'",
#  'invalid decimal literal',
#  "expected 'except' or 'finally' block",
#  'invalid decimal literal',
#  'missing a closing parenthesis ), bracket ], or brace {',
#  "'(' was never closed",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "f-string: unmatched '['",
#  'unexpected indent',
#  'unterminated f-string literal',
#  'no class or function defined after decorator',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'too many nested parentheses',
#  'keyword argument repeated: description',
#  'unterminated string literal',
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "expected 'except' or 'finally' block",
#  "'[' was never closed",
#  'too many nested parentheses',
#  'except without try block',
#  "'{' was never closed",
#  'assignment in return statement',
#  "':' expected after dictionary key",
#  'too many levels of indentation',
#  'invalid syntax. perhaps you forgot a comma?',
#  "f-string: expecting a valid expression after '{'",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 345",
#  'missing a closing parenthesis ), bracket ], or brace {; incomplete statement',
#  'finally block with incorrect indentation',
#  "'{' was never closed",
#  'else without if block',
#  "f-string: single '}' is not allowed",
#  "unmatched ']'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "expected 'else' after 'if' expression",
#  'missing docstring quote',
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "cannot assign to subscript here. maybe you meant '==' instead of '='?",
#  'did you forget parentheses around the comprehension target?',
#  'unterminated string literal',
#  'expected an indented block after function definition on line 9',
#  'keyword argument repeated: platforms',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'else without if block',
#  "annotated name 'marriage_rename_list' can't be global",
#  'else without if block',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "'{' was never closed",
#  'f-string: invalid syntax',
#  'too many nested parentheses',
#  'else without if block',
#  'missing closing parenthesis, incomplete translation',
#  "'{' was never closed",
#  "cannot assign to literal here. maybe you meant '==' instead of '='?",
#  'unterminated string literal',
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "expected 'except' or 'finally' block",
#  "'[' was never closed",
#  "expected 'except' or 'finally' block",
#  'two for loop in one statement without any seperation',
#  "annotated name '_sex_positioning_data' can't be global",
#  'except without try block',
#  "'break' outside loop",
#  "default 'except:' must be last",
#  'incorrect use of function argument in definition',
#  'unterminated string literal',
#  "expected 'except' or 'finally' block",
#  "'{' was never closed",
#  "f-string: single '}' is not allowed",
#  "'break' outside loop",
#  'else without if block',
#  'unindent does not match any outer indentation level',
#  'missing docstring quote',
#  "f-string: expecting a valid expression after '{'",
#  "'[' was never closed",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  'else without if block',
#  "'{' was never closed",
#  "unmatched ']'",
#  "'continue' not properly in loop",
#  "missing closing brace '}', incomplete translation",
#  "'[' was never closed",
#  "f-string: expecting '!', or ':', or '}'",
#  'translation incomplete, attribute accessing syntax incomplete, trailing dot',
#  "f-string: expecting '!', or ':', or '}'",
#  'else without if block',
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 182",
#  "invalid syntax. maybe you meant '==' or ':=' instead of '='?",
#  "f-string: valid expression required before '}'",
#  "invalid character '║'",
#  'defining two key-value pairs within a single loop',
#  "annotated name '_master_settings_capture' can't be global",
#  "invalid character '❌'",
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'f-string: empty expression not allowed',
#  'else without if block',
#  'else without if block',
#  "default 'except:' must be last",
#  "'break' outside loop",
#  'missing parenthesis, incomplete translation',
#  "'{' was never closed",
#  'unindent does not match any outer indentation level',
#  "f-string: single '}' is not allowed",
#  "'break' outside loop",
#  'did you forget parentheses around the comprehension target?',
#  "expected 'except' or 'finally' block",
#  'else without if block',
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  "'{' was never closed",
#  "expected 'except' or 'finally' block",
#  'f-string expression part cannot include a backslash',
#  "expected ':'",
#  "':' expected after dictionary key",
#  'keyword argument repeated: step_sequence',
#  'keyword argument repeated',
#  "expected 'except' or 'finally' block",
#  "'(' was never closed",
#  "cannot assign to attribute here. maybe you meant '==' instead of '='?",
#  "missing closing bracket ']', incomplete translation",
#  'else without if block',
#  "no closing brace '}', incomplete translation",
#  'unexpected indent',
#  'else without if block',
#  "invalid character '：'",
#  'match without case block',
#  'no class or function defined after decorator',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  'else without if block',
#  "closing parenthesis ')' does not match opening parenthesis '{'",
#  'unterminated string literal',
#  'unexpected character after line continuation character',
#  'unterminated string literal',
#  "f-string: expecting a valid expression after '{'",
#  'unterminated string literal',
#  'break outside anyy loop',
#  'except without try block',
#  'unterminated string literal',
#  'try without except block',
#  "'(' was never closed",
#  "'{' was never closed",
#  "expected 'except' or 'finally' block",
#  'unexpected character after line continuation character',
#  "expected 'else' after 'if' expression",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "'[' was never closed",
#  'cannot delete none',
#  'incorrect structure of defining key value pairs with lambda',
#  "f-string: expecting '=', or '!', or ':', or '}'",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "'[' was never closed",
#  'cannot assign to expression',
#  'missing brace, incomplete translation',
#  'f-string: invalid syntax',
#  'else without if block',
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "f-string: single '}' is not allowed",
#  "'[' was never closed",
#  'trailing comma not allowed without surrounding parentheses',
#  "'(' was never closed",
#  'positional argument follows keyword argument unpacking',
#  "missing closing brace '}', incomplete translation",
#  'unterminated string literal',
#  'f-string: expressions nested too deeply',
#  'unterminated string literal',
#  'no function or class was defined after decorator',
#  "no closing brace '}', incomplete translation",
#  'eol while scanning string literal',
#  'unterminated string literal',
#  "'{' was never closed",
#  "'(' was never closed",
#  'cannot assign to expression',
#  'unindent does not match any outer indentation level',
#  "annotated name '_relationship_settings_capture' can't be global",
#  'else without if block',
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 39",
#  'else without if block',
#  'unexpected indent',
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  "'(' was never closed",
#  "f-string: single '}' is not allowed",
#  "'[' was never closed",
#  'unexpected indent',
#  "f-string: single '}' is not allowed",
#  "f-string: expecting '}'",
#  'except without try block',
#  "expected 'except' or 'finally' block",
#  'else without if block',
#  "missing closing brace '}', brackets ']'; incomplete translation",
#  'f-string expression part cannot include a backslash',
#  "f-string: valid expression required before '}'",
#  "default 'except:' must be last",
#  'cannot assign to literal',
#  'else without if block',
#  "closing parenthesis '}' does not match opening parenthesis '('",
#  'unindent does not match any outer indentation level',
#  'missing closing parenthesis; mismatch count',
#  'unexpected unindent',
#  "f-string: single '}' is not allowed",
#  "expected 'except' or 'finally' block",
#  'cannot assign to expression',
#  'unterminated string literal',
#  "annotated name '_menstrual_absolute_time_override' can't be global",
#  'unexpected indent',
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "closing parenthesis '}' does not match opening parenthesis '(' on line 155",
#  "'continue' not properly in loop",
#  "missing brace '}', parenthesis ')', and brackets ']'; incomplete translation",
#  'expression cannot contain assignment, perhaps you meant "=="?',
#  'unterminated string literal',
#  'invalid syntax. perhaps you forgot a comma?',
#  'invalid syntax. perhaps you forgot a comma?',
#  "'break' outside loop",
#  "f-string: single '}' is not allowed",
#  "name 'diskfullloggedcount' is assigned to before global declaration",
#  "unmatched ')'",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'unterminated string literal',
#  "expected 'else' after 'if' expression",
#  "no closing brace '}'; incomplete translation",
#  'invalid syntax. perhaps you forgot a comma?',
#  'too many nested parentheses',
#  'unindent does not match any outer indentation level',
#  "':' expected after dictionary key",
#  "no closing brace '}', incomplete translation",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "annotated name '_sex_settings_capture' can't be global",
#  'except without try block',
#  'unterminated triple-quoted string literal',
#  "annotated name '_sex_animations_playlists' can't be global",
#  'else without if block',
#  "annotated name '_menstrual_absolute_time_override' can't be global",
#  "unmatched ')'",
#  "f-string: expecting a valid expression after '{'",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 129",
#  'else without if block',
#  'missing closing parenthesis; trailing comma; incomplete translation',
#  "expected 'except' or 'finally' block",
#  "'(' was never closed",
#  'f-string: empty expression not allowed',
#  'eol while scanning string literal',
#  'no class or function defined after decorator, @str as decorator',
#  'invalid decimal literal',
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 185",
#  'keyword argument repeated: output_text',
#  'unexpected indent',
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 83",
#  'unterminated string literal',
#  'unexpected indent',
#  'f-string: invalid syntax',
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  'parameter without a default follows parameter with a default',
#  'too many levels of indentation',
#  'else without if block',
#  'unexpected character after line continuation character',
#  'invalid syntax. perhaps you forgot a comma?',
#  "'[' was never closed",
#  "expected ':'",
#  "unmatched ')'",
#  'dictionary defined as decorator; no class or function follows decorator definition',
#  "expected 'except' or 'finally' block",
#  "'{' was never closed",
#  "closing parenthesis ']' does not match opening parenthesis '{'",
#  "'{' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 28",
#  'f-string: invalid syntax',
#  'using a string as module name in improt',
#  'using <mask_*> as variable name; incomplete translation',
#  "mismatched closing brace '}'",
#  'match withiut case block; no class or function defined after decorator',
#  "'[' was never closed",
#  "'{' was never closed",
#  "'return' outside function",
#  'invalid syntax',
#  'f-string: invalid syntax',
#  "invalid character '₀'",
#  'invalid whitespace in between expression, operator connecting separate strings missing',
#  "duplicate argument 'wxxxxxxxxxxxxxxwwxxxxxwwwxwwxwwxwwwwxxwxxwxwwwxwwxwwxxxwxwxxxwwwwwxxwxwwwwxwxxxwxxxwwxwxxwwxwxwwxwwwwxxxwxxwwwxxwxxxwxxwxxwwwxwxwxxwwxxwwxwwwwxwxxwwxxxwxwwxxwwwwwwwwwxxxwxxwwwxxxwwxxwxxwwwwxxwwwxwwxxwxxxxxxwwxww' in function definition",
#  "annotated name '_relationship_settings_capture' can't be global",
#  'invalid syntax. perhaps you forgot a comma?',
#  'keyword argument repeated',
#  'unexpected indent',
#  'incorrect format for else statement',
#  "annotated name 'count' can't be global",
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  "no closing brace '}', incomplete translation",
#  'unterminated string literal',
#  'unexpected indent',
#  "'[' was never closed",
#  "closing parenthesis ')' does not match opening parenthesis '{' on line 496",
#  'else without if block',
#  "expected 'else' after 'if' expression",
#  'invalid white space in variable name, no closing brace or bracket, incorrect indent',
#  'non-default argument follows default argument',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'unexpected indent',
#  'unexpected indent',
#  "expected 'except' or 'finally' block",
#  "closing parenthesis ')' does not match opening parenthesis '[' on line 6",
#  "f-string: expecting a valid expression after '{'",
#  "'{' was never closed",
#  'unterminated string literal',
#  'unterminated triple-quoted string literal',
#  "f-string: expecting '}'",
#  "'[' was never closed",
#  "default 'except:' must be last",
#  "closing parenthesis ']' does not match opening parenthesis '('",
#  "':' expected after dictionary key",
#  'import * only allowed at module level',
#  "closing parenthesis '}' does not match opening parenthesis '['",
#  'except without try block',
#  'else without if block',
#  "expected 'else' after 'if' expression",
#  'leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers',
#  "invalid character '。'",
#  'incorrect definition of for loop',
#  "f-string: expecting a valid expression after '{'",
#  'invalid white space in variable name, no closing brace or bracket, incorrect indent',
#  "f-string: expecting '!', or ':', or '}'",
#  ...]

# %%
combined = failed_cases_df_initial["precessed_error_message"].to_list() + failed_cases_df["precessed_error_message"].to_list()

# %%
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
X = model.encode(combined, normalize_embeddings=True)  # already L2 normalized

# %%
kmeans = KMeans(n_clusters=6, n_init=50, random_state=42)
labels = kmeans.fit_predict(X)
score = silhouette_score(X, labels, metric="cosine")

# %%
map_of_labels = pd.DataFrame(columns=["error_message", "label"])

# %%
for t, lbl in zip(combined, labels):
    new_df = pd.DataFrame([[t, lbl]], columns=["error_message", "label"])
    map_of_labels = pd.concat([map_of_labels, new_df], ignore_index=True)
print("silhouette (cosine):", score)
# Out:
# silhouette (cosine): 0.3810822665691376

# %%
import joblib

# %%
# 7) Save models so you can reuse them on other datasets
joblib.dump(X, "error_vectors.joblib")
joblib.dump(kmeans, "error_kmeans.joblib")
joblib.dump(labels, "error_labels.joblib")
# Out:
# ['error_labels.joblib']

# %%
current_df = pd.read_csv("../dataset/decompiled_syntax_errors.csv")

# %%
current_df.tail()
# Out:
#                                              file_hash  \
# 378  00dbd7e6a4e3cba0b7aebf59ad0b208e091f87cb851a58...
# 379  02439a0892576359290cda6ecdd77983b95e44c55cea5c...
# 380  0233993dedeaa9aadddba7824abd009455d1843260b60c...
# 381  019e8e6a12df417f798bcb4a0bed9b98cfd93d5fb93bb1...
# 382  001709536658c0d399f5f5ae9b6178a0b28b28bddea312...
#
#                                     file  \
# 378   decompiled_exchange.cpython-312.py
# 379    decompiled_queries.cpython-312.py
# 380     decompiled_domain.cpython-312.py
# 381  decompiled_constants.cpython-312.py
# 382      decompiled_utils.cpython-312.py
#
#                                          error_message  \
# 378  unterminated string literal (detected at line ...
# 379  unexpected character after line continuation c...
# 380  invalid syntax. Perhaps you forgot a comma? (l...
# 381  unterminated string literal (detected at line ...
# 382                unexpected indent (line 60, col 20)
#
#                                      error_description  \
# 378  File "/home/diogenes/pylingual_colaboration/py...
# 379  File "/home/diogenes/pylingual_colaboration/py...
# 380  File "/home/diogenes/pylingual_colaboration/py...
# 381  File "/home/diogenes/pylingual_colaboration/py...
# 382  File "/home/diogenes/pylingual_colaboration/py...
#
#                                                  error  \
# 378  unterminated string literal (detected at line ...
# 379  unexpected character after line continuation c...
# 380  invalid syntax. Perhaps you forgot a comma? (d...
# 381  unterminated string literal (detected at line ...
# 382  unexpected indent (decompiled_utils.cpython-31...
#
#                                        error_msg_clean    cluster
# 378                        unterminated string literal  Cluster_5
# 379  unexpected character after line continuation c...  Cluster_4
# 380        invalid syntax. Perhaps you forgot a comma?  Cluster_1
# 381                        unterminated string literal  Cluster_5
# 382                                  unexpected indent  Cluster_0

# %%
unique_labels = np.unique(labels)

# %%
centroid_list = []

# %%
for lab in unique_labels:
    rows = X[labels == lab]       # subset of rows in this cluster
    if rows.shape[0] == 0:
        continue  # just in case there is an empty cluster

    centroid = rows.mean(axis=0)          # 1 x n_features (dense matrix-like)
    centroid = np.asarray(centroid).ravel()  # -> (n_features,)
    centroid_list.append(centroid)

# %%
from sklearn.preprocessing import normalize
from scipy.sparse import vstack
# Now stack as dense 2D array: (k_clusters, n_features)
centroids = np.vstack(centroid_list)

# L2-normalize rows so dot product ≈ cosine similarity
centroids = normalize(centroids)

# %%
X_current = model.encode(current_df["error_msg_clean"].to_list(), normalize_embeddings=True)

# %%
scores = X_current @ centroids.T

# %%
best_idx = np.asarray(scores.argmax(axis=1)).ravel()
assigned_labels = unique_labels[best_idx]

# %%
current_df["cluster"] = assigned_labels

# %%
current_df["cluster"]= current_df["cluster"].apply(lambda x: f"cluster_{x}")

# %%
current_df.to_csv("../dataset/decompiled_syntax_errors_clustered.csv", index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=42)
XY = pca.fit_transform(X)

# Plot
plt.figure(figsize=(7,6))
uniq = np.unique(labels)
for lab in uniq:
    m = labels == lab
    marker = "x" if lab == -1 else "o"
    plt.scatter(XY[m,0], XY[m,1], s=18, alpha=0.8, label=f"Cluster {lab}", marker=marker)

plt.title("Clusters (PCA 2D)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(loc="best", fontsize=9, frameon=True)
plt.tight_layout()
plt.show()

# %%
map_of_labels.head()

# %%
# Define the output file name
output_filename = "../dataset/cluster_messages_with_initial_file_hash.xlsx"

# Use pd.ExcelWriter as a context manager
with pd.ExcelWriter(output_filename, engine='xlsxwriter') as writer:
    for i in range(6):
        
        # Filter for the current cluster
        selected_cluster = map_of_labels[map_of_labels["label"] == i]
        
        # Define the sheet name
        sheet_name = f"Cluster_{i}"
        
        # Write this cluster's DataFrame to a specific sheet
        selected_cluster.to_excel(writer, sheet_name=sheet_name, index=False)

print(f"All clusters saved to {output_filename}")
# Out:
# All clusters saved to ../dataset/cluster_messages_with_initial_file_hash.xlsx

# %%
# from sklearn.neighbors import NearestNeighbors
# import numpy as np
# import matplotlib.pyplot as plt

# # --- Assume 'embeddings' already exists from the previous step ---
# # embeddings = model.encode(texts)

# # 1. Set min_samples
# # Let's start with a value of 5
# min_samples = 5 

# # 2. Calculate nearest neighbor distances
# # n_neighbors should be min_samples
# nn = NearestNeighbors(n_neighbors=min_samples)
# nn.fit(X)
# distances, indices = nn.kneighbors(X)

# # 3. Get the distance to the k-th neighbor (k=min_samples)
# # We sort the k-th distances (the last column of 'distances')
# kth_distances = np.sort(distances[:, min_samples-1], axis=0)

# # 4. Plot the k-distance graph
# plt.plot(kth_distances)
# plt.ylabel(f"Distance to {min_samples}-th Nearest Neighbor (eps)")
# plt.xlabel("Points (sorted by distance)")
# plt.title("K-Distance Graph (Finding the Elbow)")
# plt.grid(True)
# plt.show()

# %%
# from sklearn.cluster import DBSCAN

# # --- Assume 'embeddings' and 'texts' exist ---

# # 1. Set parameters from your analysis
# # (We'll use hypothetical values from our "elbow" plot)
# chosen_eps = 0.2 
# chosen_min_samples = 5

# # 2. Initialize and run DBSCAN
# dbscan = DBSCAN(eps=chosen_eps, min_samples=chosen_min_samples)
# dbscan.fit(X)

# # 3. Get the cluster assignments
# cluster_labels = dbscan.labels_

# print(f"Cluster assignments: {cluster_labels}")
# # Example output: [ 0  0 -1  1  1  0]

# %%
# # Find the number of unique clusters (excluding noise)
# num_clusters = len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)
# print(f"\nFound {num_clusters} clusters and {np.sum(cluster_labels == -1)} noise points.")

# # Print each cluster's texts
# for i in range(num_clusters):
#     print(f"\n--- Cluster {i} ---")
#     for j in range(len(combined)):
#         if cluster_labels[j] == i:
#             print(combined[j])

# # Print the noise points
# print("\n--- Noise Points (Label -1) ---")
# for j in range(len(combined)):
#     if cluster_labels[j] == -1:
#         print(combined[j])

# %%
# print(len(cluster_labels))

# %%
# import matplotlib.pyplot as plt
# from sklearn.decomposition import PCA
# import pandas as pd
# import numpy as np

# # --- ASSUMPTIONS ---
# # You must have these variables from your previous steps:
# # embeddings: Your (N_samples, N_features) numpy array of BERT embeddings
# # cluster_labels: The (N_samples,) numpy array of labels from dbscan.fit()

# # 1. Reduce Dimensions with PCA
# print("Running PCA to reduce dimensions for plotting...")
# pca = PCA(n_components=2, random_state=42)
# reduced_embeddings = pca.fit_transform(X)

# # 2. Create a DataFrame for easy plotting
# plot_df = pd.DataFrame({
#     'pca_dim1': reduced_embeddings[:, 0],
#     'pca_dim2': reduced_embeddings[:, 1],
#     'cluster': cluster_labels
# })

# # 3. Separate noise points from clustered points
# noise_df = plot_df[plot_df['cluster'] == -1]
# clustered_df = plot_df[plot_df['cluster'] != -1]

# # 4. Create the scatter plot
# plt.figure(figsize=(12, 8))

# # Plot noise points first (grey, smaller, slightly transparent)
# plt.scatter(noise_df['pca_dim1'], noise_df['pca_dim2'],
#             c='grey',
#             s=10,
#             alpha=0.5,
#             label='Noise (Cluster -1)')

# # Plot the clustered points
# # We use 'cluster' for color and a colormap
# scatter = plt.scatter(clustered_df['pca_dim1'], clustered_df['pca_dim2'],
#                       c=clustered_df['cluster'],
#                       cmap='viridis',  # 'viridis', 'tab20', 'Spectral' are good colormaps
#                       s=25,
#                       alpha=0.8,
#                       label='Clustered Points')

# # 5. Add labels, title, and legend
# plt.title('DBSCAN Clustering Results (Visualized with PCA)')
# plt.xlabel('PCA Component 1')
# plt.ylabel('PCA Component 2')

# # Create a legend for the clusters
# # This gets the unique cluster colors and labels them
# unique_clusters = np.unique(clustered_df['cluster'])
# if len(unique_clusters) > 0:
#     handles, labels = scatter.legend_elements()
#     # Add the "Noise" label manually to the legend
#     handles.append(plt.Line2D([0], [0], marker='o', color='w', label='Noise',
#                                markerfacecolor='grey', markersize=5))
#     labels.append('Noise (-1)')
#     plt.legend(handles=handles, labels=labels, title="Cluster")
# else:
#     plt.legend(title="Cluster") # Will just show noise if no clusters found
    
# plt.grid(True)
# # plt.savefig("dbscan_cluster_plot.png")

# # print("Plot saved as 'dbscan_cluster_plot.png'")
