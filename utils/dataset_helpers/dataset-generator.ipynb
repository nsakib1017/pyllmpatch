# %%
import os
import re
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
files = []
directory = f"{os.getenv('ROOT_FOR_FILES')}/malware_files"

# %%
def list_top_level_subdirectories(root_dir):
    # List only the top-level subdirectories
    for entry in os.listdir(root_dir):
        full_path = os.path.join(root_dir, entry)
        if os.path.isdir(full_path):
            files.append(entry)

# %%
def has_user_patches_subdir(folder_path):
    return os.path.isdir(os.path.join(folder_path, 'user_patches'))

# %%
# Ask user for a directory path
if os.path.isdir(directory):
    # print(f"Subdirectories inside '{directory}':\n")
    list_top_level_subdirectories(directory)
else:
    print("Invalid directory path.")
# Out:
# Invalid directory path.

# %%
def get_error_word_message_from_content(filepath):
    FILE_LINE_RE = re.compile(r'^\s*File "([^"]+)", line (\d+)(?:, in (.+))?')
    ERROR_LINE_RE = re.compile(r'^\s*(\w+(?:Error|Exception))(?:\s*:\s*(.*))?$')
    SORRY_LINE_RE = re.compile(r'^\s*Sorry:\s*(\w+(?:Error|Exception))\s*:\s*(.*?)\s*\(([^,]+),\s*line\s*(\d+)\)\s*$')
    error_word = []
    messages = []
    last_file = None
    last_line = None
    last_ctx = None
    with open(filepath, "r", encoding="utf-8") as f:
        for line in f:
            s = line.rstrip("\n")
            m_file = FILE_LINE_RE.match(s)
            if m_file:
                last_file = m_file.group(1)
                try:
                    last_line = int(m_file.group(2))
                except ValueError:
                    last_line = None
                last_ctx = m_file.group(3)
                continue
            m_err = ERROR_LINE_RE.match(s)
            if m_err:
                error_word.append(m_err.group(1))
                messages.append((m_err.group(2) or "").strip())
                last_file = None
                last_line = None
                last_ctx = None
                break
            # 1) Handle 'Sorry:' one-liners immediately
            m_sorry = SORRY_LINE_RE.match(line)
            if m_sorry:
                error_word.append(m_sorry.group(1))
                messages.append((m_sorry.group(2) or "").strip())
                last_file = None
                last_line = None
                last_ctx = None
                break
            
    error_word = error_word[0] if len(error_word) > 0 else None
    message = messages[0] if len(messages) > 0 else None
    # print(f"File: {filepath}, Error Word: {error_word}, Message: {message}")
    return error_word, message

# %%
def search_success_equal_line(filepath,content):
    has_module_line = False
    error_word, error_message = get_error_word_message_from_content(filepath)
    # print(error_word, error_message)
    for line in content.splitlines():
        if line.startswith('***<module>'):
            has_module_line = True
            break
    return (error_word, error_message, has_module_line)

# %%
def get_error_description_from_content(content, error_word):
    import re
    lines = content.splitlines()
    description_lines = []
    for line in lines:
        description_lines.append(line)
        if error_word and error_word in line:
            break
    description = ' '.join(description_lines)
    description = re.sub(r'\s+', ' ', description)
    return description.strip()

# %%
def get_error_message_after_word(content, error_word):
    import re
    for line in content.splitlines():
        if error_word and error_word in line:
            idx = line.find(error_word)
            if idx != -1:
                # Remove colon and whitespace after error word
                after = line[idx + len(error_word):]
                after = re.sub(r'^\s*:\s*', '', after)
                return after.strip()
    return None

# %%
def get_module_lines(content):
    module_lines = []
    for line in content.splitlines():
        if '***<module>' in line:
            module_lines.append(line)
    return module_lines

# %%
def clean_error_message(error_message):
    import re
    if not error_message:
        return None
    # Convert to lowercase
    cleaned_message = error_message.lower()
    # Remove leading and trailing whitespace
    cleaned_message = cleaned_message.strip()
    # Remove contents inside parentheses (including parentheses)
    cleaned_message = re.sub(r'\(.*?\)', '', cleaned_message)
    cleaned_message = cleaned_message.strip()
    return cleaned_message

# %%
import pandas as pd

dataframe = pd.DataFrame()
def parse_highest_equivalence_report(subdir):
    file_name = subdir
    user_patches = has_user_patches_subdir(os.path.join(directory, subdir))
    subdir_path = os.path.join(directory, subdir, "decompiler_output")
    pattern = re.compile(r"equivalence_report_(\d+)\.txt")
    max_num = -1
    max_file = None
    
    if not os.path.isdir(subdir_path):
        # print(f"Directory not found: {subdir_path}")
        return
    for fname in os.listdir(subdir_path):
        error_type = None
        match = pattern.match(fname)
        if match:
            num = int(match.group(1))
            if num > max_num:
                max_num = num
                max_file = fname
    if max_file:
        with open(os.path.join(subdir_path, max_file), "r") as f:
            content = f.read()
        error_word, error_message, has_module_line = search_success_equal_line(os.path.join(subdir_path, max_file), content)
        equivalence = not (error_word or has_module_line)
        if error_word:
            error_type = "syntactic_error"
        elif has_module_line and not error_word:
            error_type = "semantic_error"
        error_description = None
        if error_word:
            error_description = get_error_description_from_content(content, error_word)
            # if error_description:
            #     error_message = get_error_message_after_word(content, error_word)
        module_lines = get_module_lines(content)
        parsing_metadata = {"file_hash": file_name, "equivalence": equivalence, "error_type": error_type, "syntactic_error_word": error_word, "syntactic_error_message": error_message if error_message else None,  "precessed_error_message": clean_error_message (error_message) if error_message else None, "syntactic_error_description": error_description if error_word else None, "user_patches": user_patches, "semantic_error_lines": module_lines}
        new_df = pd.DataFrame([parsing_metadata])
        global dataframe
        dataframe = pd.concat([dataframe, new_df], ignore_index=True)

# %%
for file in files:
    parse_highest_equivalence_report(file)

# %%
dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Replace None with 'N/A' in the dataframe
dataframe = dataframe.fillna("None")

# Example usage after replacement
print(dataframe)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def summarize_dataframe(df):
    if df.empty:
        print("The dataframe is empty. No summaries to display.")
        return

    # Group by error type
    grouped = df.groupby("error_type").agg(
        total_data=("file_hash", "count"),
        user_patches=("user_patches", "sum"),
        equivalence=("equivalence", "sum")
    )

    print("Summary by Error Type:")
    print(grouped)

# Example usage
summarize_dataframe(dataframe)
# Out:
# The dataframe is empty. No summaries to display.

# %%
def save_dataframe_to_csv(df, file_path):
    try:
        df.to_csv(file_path, index=False)
        print(f"Dataframe successfully saved to {file_path}")
    except Exception as e:
        print(f"An error occurred while saving the dataframe: {e}")

# %%
save_dataframe_to_csv(dataframe, "dataset_summary_malware.csv")
# Out:
# Dataframe successfully saved to dataset_summary_malware.csv

# %%
files_df = pd.DataFrame(files, columns=['file_hash'])

# %%
# Find files in files_df that are not in dataframe and make it a DataFrame
files_not_processed_list = list(set(files_df['file_hash']) - set(dataframe['file_hash']))
files_not_processed_df = pd.DataFrame(files_not_processed_list, columns=['file_hash'])
print({"total_files": len(files), "files_processed": len(dataframe), "files_not_processed": len(files_not_processed_df)})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Find files in files_df that are not in dataframe and make it a DataFrame
# ----> 2 files_not_processed_list = list(set(files_df['file_hash']) - set(dataframe['file_hash']))
#       3 files_not_processed_df = pd.DataFrame(files_not_processed_list, columns=['file_hash'])
#       4 print({"total_files": len(files), "files_processed": len(dataframe), "files_not_processed": len(files_not_processed_df)})
#
# File ~/miniconda3/envs/pyllmpatch/lib/python3.13/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~/miniconda3/envs/pyllmpatch/lib/python3.13/site-packages/pandas/core/indexes/range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'file_hash'

# %%
import pandas as pd

cross_dataframe = pd.DataFrame()
def validate_missing_files(subdir):
    file_name = subdir
    subdir_path = os.path.join("decompiler_workspace", subdir, "decompiler_output")
    max_num = -1
    max_file = None
    report_found = False
    pattern = re.compile(r"equivalence_report_(\d+)\.txt")
    if not os.path.isdir(subdir_path):
        print(f"Directory not found: {subdir_path}")
        return
    else:
        print(f"Processing directory: {subdir_path}")
    for fname in os.listdir(subdir_path):
        error_type = None
        match = pattern.match(fname)
        if match:
            num = int(match.group(1))
            if num > max_num:
                max_num = num
                max_file = fname
    if max_file:
       cross_dataframe = pd.DataFrame([{"file_hash": file_name, "report_found": True}])
    else:
        print("No equivalence_report_{number}.txt file found.")

# %%
for file_hash in files_not_processed_df['file_hash']:
    validate_missing_files(file_hash)
# Out:
# Directory not found: decompiler_workspace/74475975b9fc2e15a1432b8e4930b6a8a25dd63511bbc2628ae81483dd569046/decompiler_output
# Directory not found: decompiler_workspace/be495ca4cc94405470e197a0dbeda88efa08dcc970c7ad3674b571515ad93b3f/decompiler_output
# Directory not found: decompiler_workspace/3fc08fad501f41bc1609acc74caafc253dc3d3d3215ba19486db8300339ebae9/decompiler_output
# Directory not found: decompiler_workspace/8e5d645227719a582eefe43cc8e3b6865b909612f776bda9b3ac296a36d2fb4a/decompiler_output
# Directory not found: decompiler_workspace/694be9d2458e4bee45ea07809537fbd7facb65e6429e512dc7744ad3a2631c97/decompiler_output

# %%
if(len(cross_dataframe)==0):
    print("No reports found for the missing files.")
else:
    print(cross_dataframe)
# Out:
# No reports found for the missing files.

# %%
user_patches_df = dataframe[(dataframe['user_patches'] == True)]
print(user_patches_df)
# Out:
#                                               file_hash  equivalence  \
# 8     b3948d2db1a22861bb0dab405d5859da06de6004f9e4eb...        False
# 9     0fbab93fed15bb97ee15670073261169be220a84737800...        False
# 32    6c844e2db363d0244f20ef91a27112bedd3f2d87f7e9a7...        False
# 38    35e1c0d883230b7395cc68c22d68cace5b75e984d29915...        False
# 43    bb11eca1ae9809cb2d3dc8eb25446c07664d2d88062a34...        False
# ...                                                 ...          ...
# 1993  4c18d614ed19d01782794b88be960b08638a1b738a5b4d...        False
# 2005  30c2a3578efe897569823aae1ff02950ed98c87dfe9918...        False
# 2006  bedc0c9953ef7481ea037e9f4ee71f2f449c0ff6d226f3...        False
# 2007  8dcc8d595a811e41fa010cb0ab19470e56fe2aa8ff420f...        False
# 2009  76b97d50c7b6eb3b66e8eba6e93eec261bd1c63866d15a...        False
#
#            error_type syntactic_error_word  \
# 8      semantic_error                 None
# 9      semantic_error                 None
# 32    syntactic_error          SyntaxError
# 38    syntactic_error          SyntaxError
# 43    syntactic_error          SyntaxError
# ...               ...                  ...
# 1993   semantic_error                 None
# 2005  syntactic_error          SyntaxError
# 2006  syntactic_error          SyntaxError
# 2007  syntactic_error     IndentationError
# 2009   semantic_error                 None
#
#                                 syntactic_error_message  \
# 8                                                  None
# 9                                                  None
# 32                    EOL while scanning string literal
# 38    unterminated string literal (detected at line ...
# 43                              invalid decimal literal
# ...                                                 ...
# 1993                                               None
# 2005                                     invalid syntax
# 2006               expected 'except' or 'finally' block
# 2007                                  unexpected indent
# 2009                                               None
#
#                    precessed_error_message  \
# 8                                     None
# 9                                     None
# 32       eol while scanning string literal
# 38             unterminated string literal
# 43                 invalid decimal literal
# ...                                    ...
# 1993                                  None
# 2005                        invalid syntax
# 2006  expected 'except' or 'finally' block
# 2007                     unexpected indent
# 2009                                  None
#
#                             syntactic_error_description  user_patches  \
# 8                                                  None          True
# 9                                                  None          True
# 32    File "/decompiler_workspace/6c844e2db363d0244f...          True
# 38    File "/decompiler_workspace/35e1c0d883230b7395...          True
# 43    File "/decompiler_workspace/bb11eca1ae9809cb2d...          True
# ...                                                 ...           ...
# 1993                                               None          True
# 2005  File "/decompiler_workspace/30c2a3578efe897569...          True
# 2006  File "/decompiler_workspace/bedc0c9953ef7481ea...          True
# 2007  Sorry: IndentationError: unexpected indent (in...          True
# 2009                                               None          True
#
#                                    semantic_error_lines
# 8     [***<module>.on_press: Failure detected at lin...
# 9     [***<module>.on_press: Failure detected at lin...
# 32    [***<module>: Failure: Compilation Error, ***<...
# 38                                                   []
# 43    [***<module>: Failure: Compilation Error, ***<...
# ...                                                 ...
# 1993  [***<module>.on_press: Failure detected at lin...
# 2005  [***<module>: Failure: Compilation Error, ***<...
# 2006  [***<module>.encrypt_file: Failure: Compilatio...
# 2007  [***<module>.welcome.start: Failure: Different...
# 2009  [***<module>.on_ready: Failure: Different byte...
#
# [228 rows x 9 columns]

# %%
import pandas as pd

user_patch_dataframe = pd.DataFrame()
def parse_highest_equivalence_report_user_patches(subdir):
    file_name = subdir
    subdir_path = os.path.join(directory, subdir, "user_patches")
    if not os.path.isdir(subdir_path):
        print(f"User patches directory not found: {subdir_path}")
        return
    user_patch_paths = os.listdir(subdir_path)
    for user_patch in user_patch_paths:
        patch_path = os.path.join(subdir_path, user_patch)
        if os.path.isfile(patch_path) and user_patch == "successful_patches.txt":
            with open(patch_path, "r") as f:
                lines = f.readlines()
                patch_list = [line.strip() for line in lines if line.strip()]
                patch_list_str = ", ".join(patch_list)
                new_df = pd.DataFrame([{"file_hash": file_name, "successful_patches": patch_list_str}])
                global user_patch_dataframe
                user_patch_dataframe = pd.concat([user_patch_dataframe, new_df], ignore_index=True)

# %%
for _, file in user_patches_df.iterrows():
    parse_highest_equivalence_report_user_patches(file["file_hash"])

# %%
user_patch_dataframe
# Out:
#                                              file_hash  \
# 0    b3948d2db1a22861bb0dab405d5859da06de6004f9e4eb...
# 1    0fbab93fed15bb97ee15670073261169be220a84737800...
# 2    6c844e2db363d0244f20ef91a27112bedd3f2d87f7e9a7...
# 3    bb11eca1ae9809cb2d3dc8eb25446c07664d2d88062a34...
# 4    f619aceadb90ff1c8f3672d8d76537afdca78aed008351...
# ..                                                 ...
# 123  ef06a212a389a76a0a2a494aae8c1d2c4aa0067d40cb9f...
# 124  b51833d82d7301426dcb353b3ef472636474c5f4fbd391...
# 125  6d71dff9f4bfebb7836c3cd78ac32d04a85599521d9e96...
# 126  4c18d614ed19d01782794b88be960b08638a1b738a5b4d...
# 127  76b97d50c7b6eb3b66e8eba6e93eec261bd1c63866d15a...
#
#                                     successful_patches
# 0    41240f7624c52994233fac070dcf5d2728b20892ab8b10...
# 1    00649be82665fd57b024627fb752a8b013fc71abbbd92d...
# 2    e623da8bdec452316d6b2d604bcd6afd44701b46a18d56...
# 3    37bf53d1a97553b50002da05b95374c6d1588529edeb7b...
# 4    bfe6efc89f27f5ba1c8164a29b2b1cbf94bd2dc1dbb4ed...
# ..                                                 ...
# 123  41240f7624c52994233fac070dcf5d2728b20892ab8b10...
# 124  5d3d382521351104b037ee1f2a445cbea16581fcf588f6...
# 125  56d95e3e174cb50b6635e58d139c1a0cc46f298d03195a...
# 126  242d379b5ec614dca359e18c6fbd386b712ccfdfd1c3c9...
# 127  4e628f2ebc0b1afbc4e8b57232d4d56de0de03be582c67...
#
# [128 rows x 2 columns]

# %%
user_patch_dataframe.to_csv("successfull_malware_user_patches_mapping.csv", index=False)

# %%
def summarize_dataframe(df):
    if df.empty:
        print("The dataframe is empty. No summaries to display.")
        return

    # Group by error type
    grouped = df.groupby("precessed_error_message").agg(
        total_data=("file_hash", "count"),
    )

    print("Summary by precessed_error_message:")
    print(grouped)

# Example usage
summarize_dataframe(dataframe)
# Out:
# Summary by precessed_error_message:
#                                                     total_data
# precessed_error_message
# '(' was never closed                                         4
# ':' expected after dictionary key                            1
# '[' was never closed                                         7
# 'break' outside loop                                        10
# 'continue' not properly in loop                              2
# '{' was never closed                                        70
# None                                                       571
# cannot assign to expression                                  3
# cannot assign to expression here. maybe you mea...           1
# cannot assign to function call                               2
# cannot assign to literal here. maybe you meant ...           1
# closing parenthesis ')' does not match opening ...           1
# closing parenthesis ')' does not match opening ...           2
# closing parenthesis ')' does not match opening ...           1
# closing parenthesis ')' does not match opening ...           1
# closing parenthesis ')' does not match opening ...           9
# closing parenthesis ')' does not match opening ...           1
# closing parenthesis ')' does not match opening ...           1
# closing parenthesis ')' does not match opening ...           1
# closing parenthesis ']' does not match opening ...           5
# closing parenthesis ']' does not match opening ...           1
# closing parenthesis ']' does not match opening ...           1
# closing parenthesis ']' does not match opening ...           1
# closing parenthesis '}' does not match opening ...           2
# closing parenthesis '}' does not match opening ...           1
# eol while scanning string literal                           22
# expected 'except' or 'finally' block                       179
# expression cannot contain assignment, perhaps y...           3
# f-string expression part cannot include a backs...           7
# f-string: empty expression not allowed                       2
# f-string: expecting '}'                                      3
# f-string: invalid syntax                                     1
# f-string: invalid syntax. perhaps you forgot a ...           1
# f-string: single '}' is not allowed                          4
# invalid character '╔'                                        1
# invalid character '█'                                        1
# invalid character '�'                                        2
# invalid character '🏰'                                        1
# invalid character '😔'                                        1
# invalid decimal literal                                    131
# invalid non-printable character u+001b                       2
# invalid syntax                                             274
# invalid syntax. maybe you meant '==' or ':=' in...           3
# invalid syntax. perhaps you forgot a comma?                 27
# leading zeros in decimal integer literals are n...           1
# trailing comma not allowed without surrounding ...           1
# unexpected character after line continuation ch...          12
# unexpected indent                                          129
# unexpected unindent                                          3
# unindent does not match any outer indentation l...          47
# unmatched ')'                                               10
# unmatched ']'                                               12
# unterminated f-string literal                                2
# unterminated string literal                                430

# %%
# Get unique values of syntactic_error_word
unique_error_words = dataframe["syntactic_error_word"].unique()
print("Unique syntactic_error_word values:", len(list(unique_error_words)))
module_error_count = sum(1 for word in unique_error_words if str(word).startswith("<module>"))
print(f"Entries containing <module>: {module_error_count}")
dot_not_module_count = sum(1 for word in unique_error_words if "." in str(word) and "<module>" not in str(word))
print(f"Entries containing '.' but not '<module>': {dot_not_module_count}")
# Out:
# Unique syntactic_error_word values: 3
# Entries containing <module>: 0
# Entries containing '.' but not '<module>': 0

# %%
unique_error_words = dataframe["syntactic_error_word"].unique()
print("Unique syntactic_error_word values:", list(unique_error_words))
# Out:
# Unique syntactic_error_word values: ['IndentationError', 'SyntaxError', 'None']
