# %%
import os
import re
# Read dataset_summary.csv into a pandas DataFrame
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

import sys
import difflib
from typing import List, Tuple

# %%
def read_csv_file(file_name: str) -> pd.DataFrame:
    csv_path = Path(__file__).with_name(file_name) if '__file__' in globals() else Path(file_name)
    print(f"Trying to read: {csv_path.resolve()}")
    df = pd.read_csv(csv_path)
    print('DataFrame shape:', df.shape)
    return df

# %%
df_all_data_successful_patches = read_csv_file('../successfull_user_patches_mapping.csv')
# Out:
# Trying to read: /home/diogenes/pylingual_colaboration/pylingual_download/code/successfull_user_patches_mapping.csv
# DataFrame shape: (2065, 2)

# %%
ANN_LINE_RE = re.compile(r'^\s*#\s*Line\s+\d+\s*$')  # e.g., "# Line 123"

# %%
def code_portion(s: str) -> str:
    """
    Return the code portion of a line by stripping inline Python comments.
    Examples:
      "  x = 1  # note" -> "x = 1"
      "  # only comment" -> "" (empty)
    """
    # Remove everything after first '#'
    before_hash = s.split('#', 1)[0]
    return before_hash.rstrip().lstrip()

# %%
def is_comment_only(s: str) -> bool:
    """
    True if the line is a pure comment (after stripping whitespace) or
    matches an annotation like '# Line 123'.
    """
    stripped = s.strip()
    if not stripped:
        return False  # empty isn't "comment", but will be handled via code_portion
    if stripped.startswith('#'):
        return True
    if ANN_LINE_RE.match(stripped):
        return True
    return False

# %%
def parse_unified_hunks(lines: List[str]) -> List[List[str]]:
    """
    Split a unified diff (as produced by difflib.unified_diff) into hunks,
    keeping file headers outside. Returns a list of hunk lists (including the
    '@@ ... @@' header and subsequent lines up to next hunk/file header).
    """
    hunks = []
    cur = []
    for line in lines:
        if line.startswith('@@ '):
            if cur:
                hunks.append(cur)
            cur = [line]
        elif line.startswith('--- ') or line.startswith('+++ '):
            # file headers handled by caller; end current hunk if any
            if cur:
                hunks.append(cur)
                cur = []
        else:
            if cur:
                cur.append(line)
    if cur:
        hunks.append(cur)
    return hunks

# %%
def filter_hunk_only_code_changes(hunk: List[str]) -> List[str]:
    """
    Given a single hunk (starting with '@@ ... @@'), return a filtered hunk where
    only code changes remain:
      - Keep the hunk header.
      - Within the hunk, pair '-' and '+' runs and drop pairs that are identical
        after stripping comments; also drop single '-' or '+' lines that are
        comment-only (code portion empty).
    """
    if not hunk or not hunk[0].startswith('@@ '):
        return hunk[:]  # safety: not a hunk, return unchanged

    header = hunk[0]
    body = hunk[1:]

    # Collect contiguous change lines (n=0 so we shouldn't see ' ' context lines,
    # but we guard anyway).
    dels: List[str] = []
    adds: List[str] = []
    filtered_body: List[str] = []

    def flush_pairs():
        nonlocal dels, adds, filtered_body
        i = j = 0
        while i < len(dels) or j < len(adds):
            dline = dels[i] if i < len(dels) else None
            aline = adds[j] if j < len(adds) else None

            # Helpers to extract raw content (without diff prefix)
            def raw(x: str) -> str:
                return x[1:] if x and (x.startswith('-') or x.startswith('+') or x.startswith(' ')) else (x or "")

            # Decide if lines are comment-only or code-different
            if dline is not None and aline is not None:
                dcode = code_portion(raw(dline))
                acode = code_portion(raw(aline))
                d_comment_only = (not dcode) and is_comment_only(raw(dline))
                a_comment_only = (not acode) and is_comment_only(raw(aline))

                # If code portions are exactly equal, treat as comment-only change → drop
                if dcode == acode:
                    i += 1
                    j += 1
                    continue

                # If one side is pure comment and other has no code change, drop it
                if d_comment_only and not acode:
                    i += 1
                    j += 1
                    continue
                if a_comment_only and not dcode:
                    i += 1
                    j += 1
                    continue

                # Otherwise, it's a real code change → keep both lines
                filtered_body.append(dline)
                filtered_body.append(aline)
                i += 1
                j += 1

            elif dline is not None:
                # Pure deletion with no paired addition
                dcode = code_portion(raw(dline))
                if dcode:  # has code → keep
                    filtered_body.append(dline)
                else:
                    # comment-only deletion → drop
                    pass
                i += 1

            else:  # aline is not None
                acode = code_portion(raw(aline))
                if acode:  # has code → keep
                    filtered_body.append(aline)
                else:
                    # comment-only insertion → drop
                    pass
                j += 1

        dels = []
        adds = []

    # Walk through hunk body, grouping '-' and '+' runs, flushing when we hit anything else
    for ln in body:
        if ln.startswith('-'):
            dels.append(ln)
        elif ln.startswith('+'):
            adds.append(ln)
        else:
            # context or meta (rare with n=0). Flush current run, then keep line as-is.
            flush_pairs()
            # Optional: if you want to *never* show context, skip adding ln.
            # Here we skip context to satisfy "only display differing lines".
            # filtered_body.append(ln)  # <-- keep if you want context
    flush_pairs()

    if not filtered_body:
        return []  # drop entire hunk if nothing but comments changed

    return [header] + filtered_body

# %%
# Base directory where all these hash-named folders live
BASE_DIR = Path("../../decompiler_workspace")   # change to your root folder

# OUT_DIR = Path("../diffs")        # where to store diffs
# OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
def read_file(path: Path):
    try:
        return path.read_text(encoding="utf-8").splitlines(keepends=True)
    except UnicodeDecodeError:
        return path.read_text(encoding="latin-1", errors="replace").splitlines(keepends=True)

# %%
def s(p): return os.fspath(p)

# %%
from typing import Optional, Tuple
INDENTED_RE = re.compile(r"^indented_(\d+)(?:\.[^.]+)?$")  # matches indented_12 or indented_12.py

def highest_indented_file(
    directory: Path | str,
    pattern: str = "indented_*"  # change to "indented_*.py" to require .py
) -> Optional[Tuple[Path, int]]:
    """
    Return (path, idx) for the highest-numbered file named like 'indented_{idx}[.ext]'
    in the given directory. Returns None if none found.
    """
    directory = Path(directory)
    best: Optional[Tuple[Path, int]] = None

    for p in directory.glob(pattern):
        if not p.is_file():
            continue
        m = INDENTED_RE.match(p.name)
        if not m:
            continue
        n = int(m.group(1))
        if best is None or n > best[1]:
            best = (p, n)
    return best

# %%
def generate_diff(old_file: str, new_file: str) -> Tuple[List[str], str]:
    out_file =  BASE_DIR / file_hash / "user_patches" / "source_diffs.txt"

    with open(old_file, 'r', encoding='utf-8') as f:
        old_lines = f.readlines()
    with open(new_file, 'r', encoding='utf-8') as f:
        new_lines = f.readlines()

    # Make a unified diff over originals (keeps true line numbers in hunk headers)
    raw_diff = list(difflib.unified_diff(
        old_lines, new_lines,
        fromfile=old_file, tofile=new_file,
        lineterm="",n=5  # n=0 to minimize context 
    ))

    # Separate file headers and hunks
    out_lines: List[str] = []
    # Always keep file headers if present
    for ln in raw_diff:
        if ln.startswith('--- ') or ln.startswith('+++ '):
            out_lines.append(ln)

    # Parse hunks and filter
    hunks = parse_unified_hunks(raw_diff)
    for h in hunks:
        filtered = filter_hunk_only_code_changes(h)
        if filtered:
            out_lines.extend(filtered)

    text = "\n".join(out_lines)
    if out_file:
        with open(out_file, "w", encoding="utf-8") as f:
            f.write(text + ("\n" if text and not text.endswith("\n") else ""))
        print(f"Wrote filtered diff to {out_file}")
    else:
        print(text)

# %%
from pathlib import Path

def norm_str(x: str | None) -> str | None:
    if x is None:
        return None
    s = str(x).strip()
    return None if s == "" or s.lower() == "nan" else s

for idx, row in df_all_data_successful_patches.iterrows():
    file_hash = norm_str(row.get("file_hash"))
    patch_hash = norm_str(row.get("successful_patches"))

    # Skip rows with missing values
    if not file_hash or not patch_hash:
        print(f"⚠️  Skip row {idx}: missing file_hash or successful_patches")
        continue

    old_dir = BASE_DIR / file_hash / "decompiler_output"
    # highest_indented_file returns Optional[Tuple[Path, int]]
    res = highest_indented_file(old_dir, pattern="indented_*.py")
    if res is None:
        print(f"⚠️  No indented_*.py in {old_dir}")
        continue
    old_file_path, max_idx = res  # unpack

    new_file_path = BASE_DIR / file_hash / "user_patches" / patch_hash / "source.py"

    # if not old_file_path.exists():
    #     print(f"❌  Missing old file: {old_file_path}")
    #     continue
    # if not new_file_path.exists():
    #     print(f"❌  Missing new file: {new_file_path}")
    #     continue

    if old_file_path.exists() and new_file_path.exists():
        print(f"Processing file_hash={file_hash}, patch_hash={patch_hash}")
        generate_diff(str(old_file_path), str(new_file_path))
    # # If generate_diff accepts Path-like arguments (recommended):
    # diff_lines, out_path_str = generate_diff(str(old_file_path, new_file_path)
    # print(f"✅  Generated diff for file_hash={file_hash}, patch_hash={patch_hash} -> {out_path_str}")

    # # If your generate_diff currently requires str, convert:
    # # diff_lines, out_path_str = generate_diff(str(old_file_path), str(new_file_path))
# Out:
# Processing file_hash=1b071182ed192b46c3663a602507bca58c08890a1a6a0fffd52f3787123d49f8, patch_hash=090083fc164802921b7a3f2f831630a7688419d21500e1a05283b1861178c1ee
# Wrote filtered diff to ../../decompiler_workspace/1b071182ed192b46c3663a602507bca58c08890a1a6a0fffd52f3787123d49f8/user_patches/source_diffs.txt
# Processing file_hash=11b1becb1c340a39803513371a438fe2568976dbaa1364f52d20225b987ef5d8, patch_hash=0c6c22354361d136b981a91f3b4fead472dd05781e5857d14ce5324e390b96d3
# Wrote filtered diff to ../../decompiler_workspace/11b1becb1c340a39803513371a438fe2568976dbaa1364f52d20225b987ef5d8/user_patches/source_diffs.txt
# Processing file_hash=f6a25baadda3fa3fdaae3edc080251abeb540e10b9752483617a1e28bd81d8c0, patch_hash=9f5ef2e81fbb379fea38d9caea6dc197a249449a5ffb75853c6caff41c561b99
# Wrote filtered diff to ../../decompiler_workspace/f6a25baadda3fa3fdaae3edc080251abeb540e10b9752483617a1e28bd81d8c0/user_patches/source_diffs.txt
# Processing file_hash=9791c6c0331b94ddf423bb19eb1d85bdeb37e9e324383585cc8c970bab3d1907, patch_hash=d93a0cb021337df172f88227aadb3b0feac53804d6b162ab790771af2c19d3a4
# Wrote filtered diff to ../../decompiler_workspace/9791c6c0331b94ddf423bb19eb1d85bdeb37e9e324383585cc8c970bab3d1907/user_patches/source_diffs.txt
# Processing file_hash=7f5d859f525b7d93810b0373e2887e1589bec13d69a8d3759847eb018478a138, patch_hash=e9acb35bb14718c49e6988cd7d6425a3824d4e35c53dbffb6cdeb0c9065cf7f6
# Wrote filtered diff to ../../decompiler_workspace/7f5d859f525b7d93810b0373e2887e1589bec13d69a8d3759847eb018478a138/user_patches/source_diffs.txt
# Processing file_hash=6e089a9779698aaa25592c4d314109a7ec614ae58fdda51f723333fe2b83defd, patch_hash=04b1652ed451662c0cfbbb799272bbe3b8dea68739c5df10f96832fed256a7c3
# Wrote filtered diff to ../../decompiler_workspace/6e089a9779698aaa25592c4d314109a7ec614ae58fdda51f723333fe2b83defd/user_patches/source_diffs.txt
# Processing file_hash=4ca77f0205cd35231c257f13a126878b52e0795c186f838e2327d62dbdfea49b, patch_hash=6bfb585f644590e5890aa7ac56cb9baa548a21b30b9b560169e45ca25286ffb5
# Wrote filtered diff to ../../decompiler_workspace/4ca77f0205cd35231c257f13a126878b52e0795c186f838e2327d62dbdfea49b/user_patches/source_diffs.txt
# Processing file_hash=e1851bf5534c9d760cdf9e6a980ecf10935bd579a3b44c6aae033c2361dd1d54, patch_hash=58938049a7efc405967068980d82753b50e8748954f1e8a4f9208697d15ffaf2
# Wrote filtered diff to ../../decompiler_workspace/e1851bf5534c9d760cdf9e6a980ecf10935bd579a3b44c6aae033c2361dd1d54/user_patches/source_diffs.txt
# Processing file_hash=820b40631557a1271c05b58d1a121b45ac4d1e919a941e34f88a0a5204ac3152, patch_hash=c025e180cc51a562d739ce4cdd3b892543f0425cc58c9f2d78d0546d3a8183db
# Wrote filtered diff to ../../decompiler_workspace/820b40631557a1271c05b58d1a121b45ac4d1e919a941e34f88a0a5204ac3152/user_patches/source_diffs.txt
# Processing file_hash=da87c7307949168c43bf00e4dfed5358dd09f1fe7a2e8cf6bdc25de4216b40a9, patch_hash=215e83cef740b537999e53f5d4fc2e7f24f1211d07ea015aa864636349f681b5
# Wrote filtered diff to ../../decompiler_workspace/da87c7307949168c43bf00e4dfed5358dd09f1fe7a2e8cf6bdc25de4216b40a9/user_patches/source_diffs.txt
# Processing file_hash=2d70abf29ee63eb4e82c2a8424d2565e1b8e2edd4a82518ab51a2e6d9a6a83e2, patch_hash=c101ac317488e612158821bb3181805c7f6737b8e22d0512be2f7f9180f8ee7f
# Wrote filtered diff to ../../decompiler_workspace/2d70abf29ee63eb4e82c2a8424d2565e1b8e2edd4a82518ab51a2e6d9a6a83e2/user_patches/source_diffs.txt
# Processing file_hash=2171173fce22d45bec32df119d48628f653ea55f13375537742e21db9a529f64, patch_hash=9f5ef2e81fbb379fea38d9caea6dc197a249449a5ffb75853c6caff41c561b99
# Wrote filtered diff to ../../decompiler_workspace/2171173fce22d45bec32df119d48628f653ea55f13375537742e21db9a529f64/user_patches/source_diffs.txt
# Processing file_hash=dbd0c9c76d7ff6d7a486c8cfeda3f6fc97ad527ec957869b99081f8ad58fc3a5, patch_hash=06c82e527d3708175de6a8674606dad180a26819f75532a74cd1ba4979bed72b
# Wrote filtered diff to ../../decompiler_workspace/dbd0c9c76d7ff6d7a486c8cfeda3f6fc97ad527ec957869b99081f8ad58fc3a5/user_patches/source_diffs.txt
# Processing file_hash=371b5f72186c555702a4a11360636cb97a1d6ec93a603a0ae88034834b639415, patch_hash=3c4c45c78d7b81f34ea66023feb910afa29134d77ed158c473a57ea2ffd18f26
# Wrote filtered diff to ../../decompiler_workspace/371b5f72186c555702a4a11360636cb97a1d6ec93a603a0ae88034834b639415/user_patches/source_diffs.txt
# Processing file_hash=01d4c882c218f218b99b96f154129c8a74bdff112addcfff06f3e3ee5a488294, patch_hash=8c6c14838f26f99603b2cf6f5ec2572f70f4464e5d64bf536f333fa66921185a
# Wrote filtered diff to ../../decompiler_workspace/01d4c882c218f218b99b96f154129c8a74bdff112addcfff06f3e3ee5a488294/user_patches/source_diffs.txt
# Processing file_hash=9b40a8a0e31c34aa984ac4166017c9e17692855af0084aa8844429ecb93cbc91, patch_hash=e4db294ffbe7be1688599fdcce7ae0ab6b6b2c07b146c06dc3b178c8b06a4232
# Wrote filtered diff to ../../decompiler_workspace/9b40a8a0e31c34aa984ac4166017c9e17692855af0084aa8844429ecb93cbc91/user_patches/source_diffs.txt
# Processing file_hash=664c0b73845774ac12ded4f0da730c07fe5ae8423c4ca7a220cf78eb064492f3, patch_hash=12bce7566de2e780e56239aeecbd5a71131e84d9cee7e7b3ab0c9f945b92ecab
# Wrote filtered diff to ../../decompiler_workspace/664c0b73845774ac12ded4f0da730c07fe5ae8423c4ca7a220cf78eb064492f3/user_patches/source_diffs.txt
# Processing file_hash=7553bdbf6134750d064fee17c06b89e9753ba30f904a062763ab81a4dc91a1c4, patch_hash=8eeec3e8d5200a69364633da70c102c2efdf9ed63713f1c44203bf0b877a1c50
# Wrote filtered diff to ../../decompiler_workspace/7553bdbf6134750d064fee17c06b89e9753ba30f904a062763ab81a4dc91a1c4/user_patches/source_diffs.txt
# Processing file_hash=33731569886221cef6e735767233071fe3077acc4aa770668a248b60e5761fe8, patch_hash=0600e6a85753a9bf7b58460c1c42938ffc373c51115362b65a485830d34c4488
# Wrote filtered diff to ../../decompiler_workspace/33731569886221cef6e735767233071fe3077acc4aa770668a248b60e5761fe8/user_patches/source_diffs.txt
# Processing file_hash=c676f15b53f8e17668a7c085c46b5b64c5f8935ea6b6601edb5938abe0abc1bd, patch_hash=408a6173b14f4abc9f45a29f758693eababb4956d896d7b3c533291b08e4e5d4
# Wrote filtered diff to ../../decompiler_workspace/c676f15b53f8e17668a7c085c46b5b64c5f8935ea6b6601edb5938abe0abc1bd/user_patches/source_diffs.txt
# Processing file_hash=56d7fc7838b4a09ef9e3a63096d63bdf698349ead158a1bf88149b2d0d90ef61, patch_hash=7cce2a60219b987d1adff715f2e2a871bd6c2e495e8713ba1e17515ea2cae8e3
# Wrote filtered diff to ../../decompiler_workspace/56d7fc7838b4a09ef9e3a63096d63bdf698349ead158a1bf88149b2d0d90ef61/user_patches/source_diffs.txt
# Processing file_hash=3e20938f211ab9a2394389adfc46bf8126642f672eca020c6274b33461bc330f, patch_hash=0add91d1e9948a60cca4ddbb3543e6b28c56aadf3dad6491d7f1b4f650038993
# Wrote filtered diff to ../../decompiler_workspace/3e20938f211ab9a2394389adfc46bf8126642f672eca020c6274b33461bc330f/user_patches/source_diffs.txt
# Processing file_hash=14e5f5be364992562d173da4216737dbafec9c58351848ff584033c847dede31, patch_hash=5131d3092b44e56c2e2ac92c96265e9cfc68dea3b6bedba761800b3c6edb9166
# Wrote filtered diff to ../../decompiler_workspace/14e5f5be364992562d173da4216737dbafec9c58351848ff584033c847dede31/user_patches/source_diffs.txt
# Processing file_hash=7495781f4cb98737546a8de4b67a005e52de0e44ee079107cbc3304c3d5adb2e, patch_hash=f38274cba02c495139943d1f66f510a742c183d6e3c1390bda497d8fb1cf046d
# Wrote filtered diff to ../../decompiler_workspace/7495781f4cb98737546a8de4b67a005e52de0e44ee079107cbc3304c3d5adb2e/user_patches/source_diffs.txt
# Processing file_hash=4c18d614ed19d01782794b88be960b08638a1b738a5b4d6180d78b686ab6612a, patch_hash=242d379b5ec614dca359e18c6fbd386b712ccfdfd1c3c900c1aa979834460bfe
# Wrote filtered diff to ../../decompiler_workspace/4c18d614ed19d01782794b88be960b08638a1b738a5b4d6180d78b686ab6612a/user_patches/source_diffs.txt
# Processing file_hash=1a7ee254289c17101de589d68055f0f502f018b1273cf6417fb437d9b1e1db2d, patch_hash=a22fc9f8f9202e7939e5d64b3b99c332f9f3ef97937e62eda1949e7d342e932b
# Wrote filtered diff to ../../decompiler_workspace/1a7ee254289c17101de589d68055f0f502f018b1273cf6417fb437d9b1e1db2d/user_patches/source_diffs.txt
# Processing file_hash=ab22c47be0c69a2f4c8c33a8e1688f0921d9abaad832de7089b4d7a5b3b72545, patch_hash=3d51abf51ca5f2fef4410dcbb6d5eb65e76dc4f7bbb20431873379c75144da36
# Wrote filtered diff to ../../decompiler_workspace/ab22c47be0c69a2f4c8c33a8e1688f0921d9abaad832de7089b4d7a5b3b72545/user_patches/source_diffs.txt
# Processing file_hash=dfa4c2ff526fd44c4c8c4a9a20a0bbac50e1dbe9d3cd2611f24beedca5e0634b, patch_hash=96a7574960cb8c7f1744bfbf360abefaa8d585c56e9ca1c7c2adf07a32b5aa89
# Wrote filtered diff to ../../decompiler_workspace/dfa4c2ff526fd44c4c8c4a9a20a0bbac50e1dbe9d3cd2611f24beedca5e0634b/user_patches/source_diffs.txt
# Processing file_hash=9a7a7c6bba382df9eba0a996e9d8d9172d5b9c1cab1d2410a6785081712bfd4c, patch_hash=9552d9b7f073cc2dafe9e7985b018e8e1fb464201bec39a6b5861fb66ca97e7a
# Wrote filtered diff to ../../decompiler_workspace/9a7a7c6bba382df9eba0a996e9d8d9172d5b9c1cab1d2410a6785081712bfd4c/user_patches/source_diffs.txt
# Processing file_hash=ba8feed4458d3f5aa00e16499896aa9759ef0c28bbe301f2b977f4c0516e652a, patch_hash=ad982b791cf1f54a4e84918147771868bde271ffc0bd12cdcb08a72fb4b8bb15
# Wrote filtered diff to ../../decompiler_workspace/ba8feed4458d3f5aa00e16499896aa9759ef0c28bbe301f2b977f4c0516e652a/user_patches/source_diffs.txt
# Processing file_hash=5f466e7205e9ea32bc26003036299add39485d51c3bd69510558d5e6cfd0c7aa, patch_hash=de618d87dd159eaac42ee87e5a4e3b98eebc31be4102b74d8a285311f6cc03d8
# Wrote filtered diff to ../../decompiler_workspace/5f466e7205e9ea32bc26003036299add39485d51c3bd69510558d5e6cfd0c7aa/user_patches/source_diffs.txt
# Processing file_hash=ecf11f0008ab52550494a6dae1438d044adb36edd55e083a0192afb843c96955, patch_hash=b0a5954cfea4904376b029f2f1963226047586dee868ff24250bd151a382d1d7
# Wrote filtered diff to ../../decompiler_workspace/ecf11f0008ab52550494a6dae1438d044adb36edd55e083a0192afb843c96955/user_patches/source_diffs.txt
# Processing file_hash=f2268e6e160be5d043faaf33fbce932e09a08a9c79219bc340df68672d66191f, patch_hash=9d2fcf88663ee091c12558fa6b2d1c7d9307c78ae20ff5e9dbc0089b7e667991
# Wrote filtered diff to ../../decompiler_workspace/f2268e6e160be5d043faaf33fbce932e09a08a9c79219bc340df68672d66191f/user_patches/source_diffs.txt
# Processing file_hash=f9d844fc0e5ab4caeb5a729a59217a9888b59ce607f7597fbd73a746e0485d93, patch_hash=8bc2fcbffd7821690f546d2de15f48fed9d77032772b0c97a598ca1c451a7a61
# Wrote filtered diff to ../../decompiler_workspace/f9d844fc0e5ab4caeb5a729a59217a9888b59ce607f7597fbd73a746e0485d93/user_patches/source_diffs.txt
# Processing file_hash=76b97d50c7b6eb3b66e8eba6e93eec261bd1c63866d15acafc7712a8ca3fb79d, patch_hash=4e628f2ebc0b1afbc4e8b57232d4d56de0de03be582c67b7a9cc5c8bc230dff7
# Wrote filtered diff to ../../decompiler_workspace/76b97d50c7b6eb3b66e8eba6e93eec261bd1c63866d15acafc7712a8ca3fb79d/user_patches/source_diffs.txt
# Processing file_hash=807053a2b8989d887d093dad92ee0b622ac21a8b4dd9c4ca01303b960a2278f7, patch_hash=0f03fb861d35b3279259265e1b83309a22bbe25f21ab1d575b3999687af63773
# Wrote filtered diff to ../../decompiler_workspace/807053a2b8989d887d093dad92ee0b622ac21a8b4dd9c4ca01303b960a2278f7/user_patches/source_diffs.txt
# Processing file_hash=dea86a39d440448626a63f860412c80da11bd6500c2c7fb4f2b7c01261d3a358, patch_hash=29f236bf3a7c6a3952549a67e251784de2f197567cc384ec8c3d72acbeb793bd
# Wrote filtered diff to ../../decompiler_workspace/dea86a39d440448626a63f860412c80da11bd6500c2c7fb4f2b7c01261d3a358/user_patches/source_diffs.txt
